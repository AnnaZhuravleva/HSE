# %% [markdown]
# Стоп слова, лемматизатор:

# %%
import pandas as pd
import pymorphy2 as pm2
import re
import nltk
nltk.download("stopwords")
from matplotlib import pyplot
# %matplotlib inline
from gensim.models import Word2Vec
import string
#--------#
# Out:
# [nltk_data] Error loading stopwords: <urlopen error [WinError 10060]
# [nltk_data]     Попытка установить соединение была безуспешной, т.к.
# [nltk_data]     от другого компьютера за требуемое время не получен
# [nltk_data]     нужный отклик, или было разорвано уже установленное
# [nltk_data]     соединение из-за неверного отклика уже подключенного
# [nltk_data]     компьютера>

# %%
#Create lemmatizer and stopwords list
from nltk.corpus import stopwords
nltk.download('punkt')
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
russian_stopwords = stopwords.words("russian") + ['onca', 'хищный']
import nltk
# Out:
# [nltk_data] Error loading punkt: <urlopen error [WinError 10060]
# [nltk_data]     Попытка установить соединение была безуспешной, т.к.
# [nltk_data]     от другого компьютера за требуемое время не получен
# [nltk_data]     нужный отклик, или было разорвано уже установленное
# [nltk_data]     соединение из-за неверного отклика уже подключенного
# [nltk_data]     компьютера>

# %% [markdown]
# Данные:

# %%
data = pd.read_csv('jaguar.csv')
pmm = pm2.MorphAnalyzer()

# %% [markdown]
# Удаление стоп слов и лемматизация:

# %%
def parse(text):
    text = re.sub(r'[^\w\s]','',text)
    text = [pmm.normal_forms(x)[0] for x in text.split() if x not in russian_stopwords]
    return text

# %%
#def tokenize_ru(file_text):
#    tokens = word_tokenize(file_text)
#    #tokens = [i for i in tokens if (i not in string.punctuation)]
#    stop_words = stopwords.words('russian') + ['onca']
#    tokens = [i for i in tokens if (i not in stop_words)]
#    tokens = [i.replace("«", "").replace("»", "") for i in tokens]
#    return tokens

# %% [markdown]
# Очищенный текст:

# %%
#clean = sent_tokenize(data['body'], 'russian')
#clean = clean.apply(parse)
clean = data['body'].apply(parse)
abstracts = [[word for word in clean if word not in russian_stopwords] for c in clean]

# %%
clean

#model = Word2Vec(abstracts[0], size=300, window=5, min_count=5, iter=10)
#model.init_sims(replace = True)
#model.save("word2vec.model")
# Out:
# 0     [ягуар, panthera, вид, хищный, млекопитающее, ...
# 1     [на, вид, американский, зверь, вылить, леопард...
# 2     [ягуар, хищник, семейство, кошачий, принадлежа...
# 3     [название, название, ягуар, предположительно, ...
# 4     [ягуар, относиться, один, самый, крупный, живо...
# 5     [один, крупный, хищный, млекопитающее, семейст...
# 6     [в, влажный, тропический, леса, центральный, ю...
# 7     [ягуар, крупный, хищник, южный, америка, этот,...
# 8     [ягуар, млекопитающее, семейство, кошачий, сво...
# 9     [большой, грациозный, кошка, ягуар, обитать, и...
# 10    [jaguar, напиток, jaguar, слабоалкогольный, га...
# 11    [слабоалкогольный, напиток, ягуар, самый, попу...
# 12    [jaguar, популярный, мир, энергетический, напи...
# 13    [яга, это, легенда, как, свой, время, легенда,...
# 14    [напиток, ягуар, алкогольный, энергетик, напит...
# 15    [слабоалкогольный, энергетический, напиток, яг...
# 16    [напиток, ягуар, jaguar, начать, появляться, р...
# 17    [энергетический, алкогольный, напиток, право, ...
# 18    [слогать, рекламный, кампания, jaguar, дикий, ...
# 19    [jaguar, русск, ягуар, алкогольный, газировать...
# 20    [британский, автомобилестроительный, компания,...
# 21    [история, создание, компания, jaguar, начинать...
# 22    [купить, автомобиль, jaguar, москва, доступный...
# 23    [jaguar, ягуар, английский, компания, специали...
# 24    [салон, автобиография, являться, официальный, ...
# 25    [история, компания, ягуар, jaguar, cars, ltd, ...
# 26    [корень, марка, jaguar, уходить, английский, к...
# 27    [ягуар, английский, автомобильный, компания, с...
# 28    [jaguar, марка, автомобиль, принадлежащий, инд...
# 29    [каждый, новый, модель, jaguar, проходить, про...
# 30    [франсис, вебер, это, знаковый, фигура, францу...
# 31    [ягуар, приключенческий, комедийный, боевик, и...
# 32    [когдато, давно, помоему, жаркий, летний, день...
# 33    [вы, надоесть, крепкий, алкогольный, напиток, ...
# 34    [перефразировать, старый, лозунг, советский, у...
# 35    [классический, персонаж, французский, кино, жа...
# 36    [ягуар, оригинальный, название, le, jaguar, пр...
# 37    [когда, маленький, телевизор, часто, показыват...
# 38    [в, центр, событие, французский, комедия, ягуа...
# 39    [этот, яркий, остросюжетный, приключенческий, ...
# 40    [инструкция, швейный, машина, mini, jaguar, ин...
# 41    [электромеханический, швейный, машина, jaguar,...
# 42    [данный, раздел, каталог, продукция, наш, мага...
# 43    [недорогой, швейный, машинка, хороший, помощни...
# 44    [швейный, машинка, дом, ягуар, хороший, модель...
# 45    [компактный, электромеханический, швейный, маш...
# 46    [jaguar, 333, это, один, современный, домашний...
# 47    [компания, jaguar, основать, япония, 1949, год...
# 48    [неожиданно, наличие, светодиодный, освещение,...
# 49    [компактный, электромеханический, швейный, маш...
# Name: body, dtype: object

# %%
abstracts[0]
# Out:
# [['ягуар',
#   'panthera',
#   'вид',
#   'хищный',
#   'млекопитающее',
#   'семейство',
#   'кошачий',
#   'четыре',
#   'представитель',
#   'род',
#   'пантера',
#   'лата',
#   'panthera',
#   'который',
#   'относиться',
#   'подсемейство',
#   'больший',
#   'кошка',
#   'единственный',
#   'представитель',
#   'род',
#   'территория',
#   'северный',
#   'южный',
#   'америка',
#   'три',
#   'размер',
#   'мир',
#   'самый',
#   'крупный',
#   'новый',
#   'свет',
#   'представитель',
#   'семейство',
#   'кошачий',
#   'ареал',
#   'вид',
#   'простираться',
#   'мексика',
#   'юг',
#   'парагвай',
#   'север',
#   'аргентина',
#   'длина',
#   'тело',
#   'хвост',
#   '112185',
#   'сантиметр',
#   'хвост',
#   '4575',
#   'сантиметр',
#   'масса',
#   '36113',
#   'килограмм',
#   'основное',
#   '6090',
#   'килограмм',
#   'отдельный',
#   'случай',
#   '120',
#   'килограмм',
#   'рекорд',
#   'природа',
#   'составлять',
#   '158',
#   'килограмм',
#   'самка',
#   '20',
#   'маленький',
#   'лёгкий',
#   'обычный',
#   'нормальный',
#   'взрослый',
#   'самец',
#   'крупный',
#   'подвид',
#   'весить',
#   'около',
#   '90110',
#   'килограмм',
#   'среднее',
#   'около',
#   '9095',
#   'килограмм',
#   'самка',
#   '6080',
#   'килограмм',
#   'высота',
#   'холка',
#   'составлять',
#   '6376',
#   'сантиметр',
#   'внешне',
#   'ягуар',
#   'очень',
#   'похожий',
#   'леопард',
#   'значительно',
#   'превосходить',
#   'размер',
#   'самый',
#   'крупный',
#   'ягуар',
#   'обитать',
#   'бразильский',
#   'штат',
#   'матугроса',
#   'в',
#   'зона',
#   'обитание',
#   'ягуар',
#   'поиспански',
#   'называться',
#   'разный',
#   'otorongo',
#   'jaguar',
#   'yaguareté',
#   'yaguar',
#   'onza',
#   'tigre',
#   'tigre',
#   'americano',
#   'мексиканец',
#   'называть',
#   'язык',
#   'науатль',
#   'ocelotl',
#   'ошибочно',
#   'совпадать',
#   'общепринятый',
#   'название',
#   'оцелот',
#   'последний',
#   'ацтекский',
#   'название',
#   'tlatlauhquiocélotl',
#   'на',
#   'один',
#   'язык',
#   'майя',
#   'называться',
#   'balam',
#   'мапучий',
#   'nahuel',
#   'кечуа',
#   'uturuncu',
#   'uturunku',
#   'unqa',
#   'на',
#   'больший',
#   'часть',
#   'латинский',
#   'америка',
#   'называть',
#   'просто',
#   'tigre',
#   'тигр',
#   'хотя',
#   'родство',
#   'тигр',
#   'довольно',
#   'отдалённый',
#   'бразилия',
#   'португальский',
#   'называться',
#   'onça6',
#   'довольно',
#   'часто',
#   'слово',
#   'yahuar',
#   'явар',
#   'йавар',
#   'yaguar',
#   'ягуар',
#   'встречаться',
#   'язык',
#   'кечуа',
#   'правило',
#   'испанец',
#   'кечуанский',
#   'звук',
#   'hua',
#   'ва',
#   'уа',
#   'записываться',
#   'gua',
#   'гуа',
#   'кечуа',
#   'согласный',
#   'год',
#   'оно',
#   'значит',
#   'кровь',
#   'иначе',
#   'связать',
#   'кровь',
#   'это',
#   'слово',
#   'составной',
#   'частью',
#   'имя',
#   'правитель',
#   'инк',
#   'ягуар',
#   'укиснуть',
#   'yaguar',
#   'huquiz',
#   'упоминаться',
#   'фернандо',
#   'монтесиноса7',
#   'явар',
#   'вакак',
#   'плачущий',
#   'кровь',
#   'упоминаться',
#   'весь',
#   'перуанский',
#   'хронист',
#   'начинать',
#   '1540ха',
#   'годов8',
#   'слово',
#   'яварягуар',
#   'входить',
#   'множество',
#   'кечуанский',
#   'словосочетание',
#   'allin',
#   'yahuar',
#   'yahuarniyoc',
#   'знатный',
#   'человек',
#   'хороший',
#   'род',
#   'хорошеть',
#   'кровикаста',
#   'yahuar',
#   'yahuar',
#   'полный',
#   'кровь',
#   'окровавленный',
#   'yahuar',
#   'macintin',
#   'родственник',
#   'многие',
#   'другой',
#   'возможно',
#   'данный',
#   'слово',
#   'также',
#   'определение',
#   'хищный',
#   'животный',
#   'кечуа',
#   'храбрый',
#   'человек',
#   'сравниваться',
#   'именно',
#   'ягуар',
#   'пумой9',
#   'получить',
#   'свой',
#   'распространение',
#   'поскольку',
#   'похожий',
#   'слово',
#   'язык',
#   'гуарань',
#   'стать',
#   'известно',
#   'европеец',
#   'значительно',
#   'поздний',
#   'активный',
#   'колонизация',
#   'парагвай',
#   'начаться',
#   '1600ха',
#   'год',
#   '70',
#   'год',
#   'поздний',
#   'колонизация',
#   'перу',
#   '1532',
#   'на',
#   'гуарань',
#   'yaguara',
#   'jaguarete',
#   'означать',
#   'зверь',
#   'убивать',
#   'один',
#   'прыжок',
#   'у',
#   'некоторый',
#   'индеец',
#   'амазонии',
#   'например',
#   'тупить',
#   'ягуар',
#   'называться',
#   'похоже',
#   'iawa',
#   'iawaraté',
#   'основной',
#   'дать',
#   'относительно',
#   'эволюция',
#   'вид',
#   'получить',
#   'помощь',
#   'палеонтологический',
#   'молекулярнофилогенетический',
#   'исследование',
#   'ягуар',
#   'единственный',
#   'представитель',
#   'род',
#   'panthera',
#   'новый',
#   'свет',
#   'и',
#   'молекулярный',
#   'палеонтологический',
#   'дать',
#   'подтверждать',
#   'близкий',
#   'родство',
#   'ягуар',
#   'другой',
#   'представитель',
#   'род',
#   'последний',
#   'общий',
#   'предок',
#   'род',
#   'ближний',
#   'родственник',
#   'дымчатый',
#   'леопард',
#   'жить',
#   '6',
#   '10',
#   'миллион',
#   'год',
#   'назад10',
#   'сам',
#   'род',
#   'возникнуть',
#   'палеонтологический',
#   'данные',
#   'примерно',
#   '38',
#   'миллион',
#   'год',
#   'назад1011',
#   'основной',
#   'морфологический',
#   'признак',
#   'свидетельствовать',
#   'наиболее',
#   'близкий',
#   'родственник',
#   'ягуар',
#   'леопард12',
#   'однако',
#   'исследование',
#   'днк',
#   'окончательно',
#   'завершить',
#   'мнение',
#   'родственный',
#   'связь',
#   'ягуар',
#   'отличаться',
#   'разный',
#   'исследователей10121314',
#   'ископаемое',
#   'останки',
#   'вымереть',
#   'вид',
#   'род',
#   'такой',
#   'европейский',
#   'ягуар',
#   'panthera',
#   'gombaszoegensis',
#   'американский',
#   'левый',
#   'panthera',
#   'leo',
#   'atrox',
#   'совмещать',
#   'характерный',
#   'признак',
#   'лев',
#   'ягуара12',
#   'анализ',
#   'митохондриальный',
#   'днк',
#   'ягуар',
#   'показать',
#   'вид',
#   'возникнуть',
#   '510',
#   '000',
#   '280',
#   '000',
#   'год',
#   'назад',
#   'поздний',
#   'предполагаться',
#   'ископаемое',
#   'останкам15',
#   'ареал',
#   'ягуар',
#   'простираться',
#   'центральный',
#   'америка',
#   'болото',
#   'сельва',
#   'мат',
#   'гроса',
#   'также',
#   'север',
#   'аргентина',
#   'самый',
#   'крупный',
#   'ягуар',
#   'обитать',
#   'бразильский',
#   'штат',
#   'матугроса',
#   'ягуар',
#   'полностью',
#   'истребить',
#   'сальвадор',
#   'уругвай',
#   'основной',
#   'место',
#   'обитание',
#   'ягуар',
#   'тропический',
#   'дождевой',
#   'леса',
#   'злаковник',
#   'зверь',
#   'встречаться',
#   'семиаридный',
#   'район',
#   'зарасти',
#   'ксерофитный',
#   'кустарник',
#   'он',
#   'встречать',
#   'горный',
#   'леса',
#   'высота',
#   '2000',
#   'метр',
#   'океанский',
#   'побережье',
#   'хищник',
#   'отыскивать',
#   'выкапывать',
#   'черепаший',
#   'яйцо',
#   'древний',
#   'останки',
#   'ягуар',
#   'датироваться',
#   'поздний',
#   'плиоцен',
#   'примерно',
#   '2',
#   'миллион',
#   'год',
#   'в',
#   'тот',
#   'время',
#   'ягуар',
#   'населять',
#   'весь',
#   'юг',
#   'нынешний',
#   'сша',
#   'последний',
#   'ягуар',
#   'убитый',
#   'около',
#   '1900',
#   'год',
#   'сейчас',
#   'ареал',
#   'ягуар',
#   'сократиться',
#   'треть',
#   'первоначальный',
#   'образ',
#   'жизнь',
#   'ягуаровый',
#   'одиночный',
#   'как',
#   'хищный',
#   'кошка',
#   'ягуар',
#   'территориальный',
#   'зверь',
#   'площадь',
#   'территория',
#   'один',
#   'ягуар',
#   'занимать',
#   '25',
#   'самка',
#   '100',
#   '120170',
#   'самцовисточник',
#   'указанный',
#   '469',
#   'день',
#   'квадратный',
#   'километр',
#   'зависимость',
#   'ландшафт',
#   'количество',
#   'дичь',
#   'как',
#   'правило',
#   'охотничий',
#   'участок',
#   'самец',
#   'форма',
#   'представлять',
#   'себя',
#   'треугольник',
#   'на',
#   'свой',
#   'территория',
#   'самец',
#   'охотиться',
#   '34',
#   'день',
#   'определённый',
#   'район',
#   'затем',
#   'переходить',
#   'участок',
#   'кроме',
#   'зверь',
#   'наведываться',
#   'определённый',
#   'пограничный',
#   'точка',
#   'каждый',
#   'пять',
#   'пятнадцать',
#   'день',
#   'по',
#   'причина',
#   'ягуар',
#   'являться',
#   'настоящее',
#   'бродяга',
#   'постоянно',
#   'шататься',
#   'сельва',
#   'ягуар',
#   'крайне',
#   'нетерпимый',
#   'другой',
#   'кошачий',
#   'частность',
#   'пума',
#   'свой',
#   'территория',
#   'довольно',
#   'миролюбивый',
#   'свой',
#   'сородич',
#   'охотничий',
#   'территория',
#   'ягуаровый',
#   'часто',
#   'пересекаться',
#   'ягуар',
#   'являться',
#   'сумеречный',
#   'хищник',
#   'он',
#   'самый',
#   'активный',
#   'охотничий',
#   'часы',
#   'приходиться',
#   'время',
#   'заход',
#   'солнце',
#   'примерно',
#   '1830',
#   '2130',
#   'рассвет',
#   '0300',
#   '0600',
#   'предпочитать',
#   'добыча',
#   'капибара',
#   'копытный',
#   'вроде',
#   'олень',
#   'маз',
#   'пекарь',
#   'тапир',
#   'но',
#   'отличие',
#   'лев',
#   'тигр',
#   'ягуар',
#   'иметь',
#   'свой',
#   'среда',
#   'обитание',
#   'огромный',
#   'стадо',
#   'разнообразный',
#   'копытный',
#   'поэтому',
#   'исторически',
#   'вынужденный',
#   'приспосабливаться',
#   'водный',
#   'охота',
#   'нападать',
#   'вода',
#   'кайман',
#   'водоплавающий',
#   'птица',
#   'змей',
#   'рыбу16',
#   'иногда',
#   'нападать',
#   'анаконд17',
#   'исключительный',
#   'случай',
#   'очень',
#   'больший',
#   'чёрный',
#   'кайманов18',
#   'который',
#   'правда',
#   'сам',
#   'убивать',
#   'ягуаровый',
#   'тот',
#   'заходить',
#   'воду19',
#   'в',
#   'рацион',
#   'ягуаровый',
#   'входить',
#   'также',
#   'обезьяна',
#   'лисица',
#   'грызун',
#   'носуха',
#   'другой',
#   'небольшой',
#   'животное',
#   'охотиться',
#   'ягуар',
#   'пресноводный',
#   'черепаха',
#   'броненосец',
#   'мощный',
#   'челюсть',
#   'способный',
#   'преодолеть',
#   'защита',
#   'на',
#   'побережье',
#   'хищничество',
#   'ягуаровый',
#   'подвергаться',
#   'яйцо',
#   'морской',
#   'черепаха',
#   'самка',
#   'выйти',
#   'отложить20',
#   'в',
#   'отличие',
#   'пума',
#   'ягуар',
#   'охотно',
#   'часто',
#   'нападать',
#   'домашний',
#   'скот',
#   'основной',
#   'метод',
#   'охота',
#   'ягуар',
#   'это',
#   'засада',
#   'высокий',
#   'трава',
#   'дерево',
#   'обычно',
#   'такой',
#   'засада',
#   'устраивать',
#   'берег',
#   'водоём',
#   'трава',
#   'троп',
#   'ведущий',
#   'водопой',
#   'при',
#   'нападение',
#   'жертва',
#   'ягуар',
#   'правило',
#   'прыгать',
#   'она',
#   'спина',
#   'бок',
#   'хватать',
#   'шея',
#   'чаща',
#   'атака',
#   'скот',
#   'ягуар',
#   'стремиться',
#   'повалить',
#   'жертва',
#   'который',
#   'сильно',
#   'смертельно',
#   'травмироваться',
#   'момент',
#   'падение',
#   'у',
#   'большинство',
#   'корова',
#   'погибший',
#   'атака',
#   'ягуаровый',
#   'сломать',
#   'шейный',
#   'позвонок',
#   'результат',
#   'падение',
#   'голов',
#   'запрокинуть',
#   'спин',
#   'в',
#   'отличие',
#   'другой',
#   'крупный',
#   'кошачий',
#   'ягуар',
#   'прокусывать',
#   'жертва',
#   'череп',
#   'хотя',
#   'обычно',
#   'точно',
#   'душить',
#   'добыча',
#   'схватить',
#   'горло',
#   'если',
#   'жертва',
#   'обнаружить',
#   'хищник',
#   'спасаться',
#   'бегство',
#   'ягуар',
#   'её',
#   'преследовать',
#   'охотник',
#   'бразилия',
#   'приписывать',
#   'ягуар',
#   'способность',
#   'гипнотизировать',
#   'жертва',
#   'ягуармеланист',
#   'чёрный',
#   'пантера',
#   'убить',
#   'добыча',
#   'ягуар',
#   'начинать',
#   'поедать',
#   'её',
#   'голов',
#   'постепенно',
#   'продвигаться',
#   'задний',
#   'часть',
#   'если',
#   'жертва',
#   'велик',
#   'хищник',
#   'оставаться',
#   'она',
#   'утолять',
#   'голод',
#   'приём',
#   'интервал',
#   '1012',
#   'часы',
#   'характерный',
#   'ягуар',
#   'питаться',
#   'падаль',
#   'поэтому',
#   'остаток',
#   'свой',
#   'жертва',
#   'возвращаться',
#   'очень',
#   'редко',
#   'на',
#   'охота',
#   'зверь',
#   'издавать',
#   'низкий',
#   'отрывистый',
#   'гортанный',
#   'ворчание',
#   'ночь',
#   'брачный',
#   'период',
#   'оглушительно',
#   'реветь',
#   'по',
#   'индейский',
#   'поверье',
#   'ягуар',
#   'способный',
#   'имитировать',
#   'крик',
#   'люба',
#   'птица',
#   'животное',
#   'подманить',
#   'случай',
#   'нападение',
#   'ягуаровый',
#   'человек',
#   'известно',
#   'очень',
#   'мало',
#   'неспровоцированный',
#   'маленький',
#   'людоедство',
#   'среди',
#   'этот',
#   'хищник',
#   'явление',
#   'исключительный',
#   'чаща',
#   'ягуар',
#   'нападать',
#   'защищаться',
#   'если',
#   'ягуар',
#   'провоцировать',
#   'обычно',
#   'агрессивный',
#   'скорее',
#   'любопытный',
#   'часто',
#   'преследовать',
#   'человек',
#   'леса',
#   'проявлять',
#   'враждебный',
#   'намерение',
#   'однако',
#   'изредка',
#   'бросаться',
#   'человек',
#   'человек',
#   'повстречать',
#   'неожиданно',
#   'ягуар',
#   'чаща',
#   'испытывать',
#   'странный',
#   'чувство',
#   'почтение',
#   'некого',
#   'удивление',
#   'вот',
#   'встреча',
#   'ягуар',
#   'писать',
#   '30х',
#   'год',
#   'xx',
#   'век',
#   'английский',
#   'путешественник',
#   'зоолог',
#   'айвено',
#   'сандерсон',
#   'я',
#   'сильно',
#   'вздрогнуть',
#   'неожиданность',
#   'нарост',
#   'изменить',
#   'очертание',
#   'стать',
#   'медленно',
#   'взбираться',
#   'ствол',
#   'я',
#   'должный',
#   'обратить',
#   'ваш',
#   'внимание',
#   'необъяснимый',
#   'очень',
#   'интересный',
#   'факт',
#   'хотя',
#   'животный',
#   'который',
#   'безошибочно',
#   'узнать',
#   'силуэт',
#   'хищник',
#   'чувствовать',
#   'похожий',
#   'необычайный',
#   'ощущение',
#   'безотчётный',
#   'ужас',
#   'который',
#   'возникать',
#   'вид',
#   'леопард',
#   'западный',
#   'африка',
#   'пронизывать',
#   'голов',
#   'пята',
#   'перед',
#   'я',
#   'дерево',
#   'какихнибудь',
#   'двенадцать',
#   'фут',
#   'ок',
#   '4',
#   'метр',
#   'припасть',
#   'ствол',
#   'ягуар',
#   'лунный',
#   'сияние',
#   'зверь',
#   'казаться',
#   'громадный',
#   'настоящий',
#   'выбелить',
#   'луна',
#   'динозавр',
#   'одурять',
#   'тошнотворный',
#   'ужас',
#   'вызывать',
#   'определённый',
#   'сезон',
#   'размножение',
#   'ягуар',
#   'самка',
#   'готовый',
#   'спаривание',
#   'три',
#   'год',
#   'жизнь',
#   'хотя',
#   'ягуар',
#   'одиночный',
#   'животный',
#   'период',
#   'свадьба',
#   'мочь',
#   'собираться',
#   'небольшой',
#   'группа',
#   'характерный',
#   'поединок',
#   'самец',
#   ...],
#  ['на',
#   'вид',
#   'американский',
#   'зверь',
#   'вылить',
#   'леопард',
#   'значительно',
#   'мощный',
#   'и',
#   'самый',
#   'дело',
#   'оба',
#   'животное',
#   'близкие',
#   'родственник',
#   'оказаться',
#   'самка',
#   'помесь',
#   'леопард',
#   'ягуар',
#   'способный',
#   'продолжение',
#   'род',
#   'у',
#   'общий',
#   'леопард',
#   'тигр',
#   'старое',
#   'свет',
#   'так',
#   'лазать',
#   'дерево',
#   'плавать',
#   'хотя',
#   'правило',
#   'охотиться',
#   'земля',
#   'у',
#   'большой',
#   'голова',
#   'мощный',
#   'челюсть',
#   'лапа',
#   'просто',
#   'огромный',
#   'ягуар',
#   'леопард',
#   'всякий',
#   'отличить',
#   'очень',
#   'похожий',
#   'пятно',
#   'крупный',
#   'некоторый',
#   'розетка',
#   'чёрный',
#   'пятнышко',
#   'центр',
#   'вода',
#   'тигр',
#   'очень',
#   'любить',
#   'любить',
#   'плавать',
#   'лёжа',
#   'бревно',
#   'вниз',
#   'река',
#   'иной',
#   'замечтаться',
#   'течение',
#   'выносить',
#   'океан',
#   'ягуар',
#   'трудо',
#   'увидеть',
#   'зато',
#   'значительно',
#   'лёгкий',
#   'услышать',
#   'он',
#   'рычать',
#   'подобно',
#   'лев',
#   'уметь',
#   'урчать',
#   'мурлыкать',
#   'он',
#   'голос',
#   'напоминать',
#   'сиплый',
#   'лающий',
#   'кашель',
#   'звук',
#   'распиливать',
#   'дерево',
#   'пока',
#   'невыясненно',
#   'означать',
#   'каждый',
#   'этот',
#   'звук',
#   'мяуканье',
#   'ягуар',
#   'связать',
#   'любовный',
#   'игра',
#   'прерывистый',
#   'синхронный',
#   'придыхание',
#   'рык',
#   'являться',
#   'территориальный',
#   'аргумент',
#   'ягуар',
#   'настоящий',
#   'воин',
#   'мощный',
#   'челюсть',
#   'огромный',
#   'прыжок',
#   'тяжёлый',
#   'вес',
#   'сокрушительный',
#   'зуб',
#   'когтить',
#   'наборчик',
#   'слабонервный',
#   'ягуар',
#   'способный',
#   'справиться',
#   'добыча',
#   'вес',
#   '250',
#   '300',
#   'килограмм',
#   'великолепный',
#   'зрение',
#   'исключительный',
#   'слух',
#   'являться',
#   'отличный',
#   'дополнение',
#   'вышеперечисленный',
#   'дотоинство',
#   'туловище',
#   'ягуар',
#   'тяжеловесный',
#   'крепкий',
#   'выглядеть',
#   'приземистый',
#   'неуклюжий',
#   'голова',
#   'массивный',
#   'строение',
#   'череп',
#   'ягуар',
#   'пожалуй',
#   'близкий',
#   'тигр',
#   'леопард',
#   'зато',
#   'окрасить',
#   'последний',
#   'размер',
#   'длина',
#   '185',
#   'метр',
#   'хвост',
#   '075',
#   'метр',
#   'высота',
#   'холка',
#   '068',
#   '076',
#   'метр',
#   'вес',
#   '160',
#   'килограмм',
#   'самка',
#   'лёгкий',
#   'самец',
#   'среднее',
#   '20',
#   'продолжительность',
#   'жизнь',
#   '10',
#   'год',
#   'природа',
#   '25',
#   'год',
#   'неволя',
#   '50',
#   'смертность',
#   'приходиться',
#   'возраст',
#   '2',
#   'год',
#   'о',
#   'точный',
#   'число',
#   'подвид',
#   'ягуар',
#   'учёный',
#   'пока',
#   'договориться',
#   'прежде',
#   'насчитывать',
#   'восемь',
#   'подвид',
#   'разделять',
#   'звереть',
#   'размер',
#   'окраска',
#   'узор',
#   'шубка',
#   'слишком',
#   'сильно',
#   'варьировать',
#   'самый',
#   'маленькая',
#   'ягуар',
#   'встречаться',
#   'гондурас',
#   'гватемала',
#   'самый',
#   'крупный',
#   'бразилия',
#   'район',
#   'матугроса',
#   'штат',
#   'граница',
#   'боливия',
#   'причём',
#   'длина',
#   'животное',
#   'колебаться',
#   '16',
#   '24',
#   'метр',
#   'треть',
#   'занимать',
#   'хвост',
#   'основной',
#   'окрас',
#   'меняться',
#   'песочный',
#   'ярка',
#   'рыжеватый',
#   'охра',
#   'туловище',
#   'покрыть',
#   'сплошной',
#   'кольцевой',
#   'пятно',
#   'также',
#   'розетка',
#   'причём',
#   'внутри',
#   'последний',
#   'шерсть',
#   'тёмный',
#   'общий',
#   'окрас',
#   'голова',
#   'широкий',
#   'мощный',
#   'лапа',
#   'чёрный',
#   'крапинка',
#   'в',
#   'нижний',
#   'часть',
#   'туловище',
#   'наблюдаетс',
#   'поперечный',
#   'рисунок',
#   'живот',
#   'присутствовать',
#   'большой',
#   'чёрный',
#   'пятно',
#   'горло',
#   'грудь',
#   'полоса',
#   'составить',
#   'слиться',
#   'воедино',
#   'крапинка',
#   'на',
#   'хвост',
#   'животное',
#   'также',
#   'заметный',
#   'узор',
#   'расположиться',
#   'рядышком',
#   'кольцевой',
#   'пятно',
#   'розетка',
#   'шерсть',
#   'внутри',
#   'светлый',
#   'ухо',
#   'ягуаровый',
#   'закруглить',
#   'снаружи',
#   'чёрный',
#   'жёлтый',
#   'пятно',
#   'посредине',
#   'нередко',
#   'встречаться',
#   'животныемеланос',
#   'внешне',
#   'очень',
#   'напоминать',
#   'чёрный',
#   'пантера',
#   'хотя',
#   'крупный',
#   'размер',
#   'выдавать',
#   'порода',
#   'беременность',
#   'длиться',
#   '13',
#   'неделя',
#   'рождаться',
#   'один',
#   'четыре',
#   'детёныш',
#   'окрасить',
#   'также',
#   'узорчатый',
#   'родитель',
#   'цвет',
#   'юниор',
#   'приглушить',
#   'матовый',
#   'пятно',
#   'телец',
#   'обычно',
#   'сплошной',
#   'чёрный',
#   'в',
#   'зоопарк',
#   'ягуар',
#   'встречаться',
#   'довольно',
#   'часто',
#   'если',
#   'браться',
#   'воспитание',
#   'сызмальства',
#   'определённый',
#   'степень',
#   'приручить',
#   'в',
#   'настоящее',
#   'время',
#   'ягуар',
#   'проживать',
#   'территория',
#   '35',
#   'градус',
#   'северный',
#   'широта',
#   'этот',
#   'цифра',
#   'называться',
#   'скорее',
#   'традиция',
#   'американский',
#   'штат',
#   'аризона',
#   'ньюмексико',
#   'техас',
#   'ягуар',
#   'практически',
#   'истребить',
#   '40',
#   'градус',
#   'южный',
#   'широта',
#   'чили',
#   'аргентина',
#   'зона',
#   'обитание',
#   'маленький',
#   'пума',
#   'жить',
#   'ягуар',
#   'степь',
#   'редколесьей',
#   'сырой',
#   'болотистый',
#   'леса',
#   'нередко',
#   'сырость',
#   'наживать',
#   'рахит',
#   'среда',
#   'обитание',
#   'мексика',
#   'аргентина',
#   'место',
#   'обитание',
#   'влажный',
#   'тропический',
#   'леса',
#   'околопустынный',
#   'кустарниковый',
#   'заросль',
#   'высота',
#   '1000',
#   'метр',
#   'вода',
#   'этот',
#   'кошка',
#   'бояться',
#   'любить',
#   'плавать',
#   'плавать',
#   'отлично',
#   'потому',
#   'обитатель',
#   'река',
#   'озеры',
#   'приходиться',
#   'кормить',
#   'себя',
#   'хищник',
#   'обед',
#   'он',
#   'попадать',
#   'водосвинка',
#   'капибара',
#   'черепаха',
#   'рыба',
#   'рыба',
#   'ягуар',
#   'охотиться',
#   'берег',
#   'вышвырива',
#   'вода',
#   'мощный',
#   'удар',
#   'лапа',
#   'очевидец',
#   'рассказывать',
#   'видеть',
#   'ягуар',
#   'выхватывать',
#   'рыба',
#   'огромный',
#   'лапа',
#   'прямо',
#   'вода',
#   'вообще',
#   'весь',
#   'американский',
#   'зверьё',
#   'приходиться',
#   'бояться',
#   'прожора',
#   'ливый',
#   'ягуар',
#   'тапир',
#   'попадать',
#   'он',
#   'обед',
#   'отнюдь',
#   'качество',
#   'сотрапезник',
#   'обезьяна',
#   'сеять',
#   'прирождённый',
#   'охотник',
#   'настигать',
#   'верхушка',
#   'дерево',
#   'приканчивать',
#   'вблизи',
#   'водопой',
#   'ягуар',
#   'бывать',
#   'активный',
#   'ночью',
#   'днём',
#   'самый',
#   'любимый',
#   'время',
#   'тревожный',
#   'смутный',
#   'сумерки',
#   'очень',
#   'часто',
#   'ягуар',
#   'сначала',
#   'закапывать',
#   'добыча',
#   'возвращаться',
#   'поедать',
#   'её',
#   'хотя',
#   'человек',
#   'немало',
#   'рассказывать',
#   'кровожадность',
#   'ягуар',
#   'слепой',
#   'неукротимый',
#   'жажда',
#   'убивать',
#   'рассказ',
#   'нередко',
#   'превращаться',
#   'россказни',
#   'ягуар',
#   'страшный',
#   'представлять',
#   'прирождённый',
#   'убийца',
#   'человек',
#   'скорее',
#   'следовать',
#   'именовать',
#   'человек',
#   'охота',
#   'ягуар',
#   'категорически',
#   'запретить',
#   'место',
#   'обитание',
#   'кроме',
#   'французский',
#   'гвиана',
#   'игнорировать',
#   'конвенция',
#   'защита',
#   'исчезать',
#   'вид'],
#  ['ягуар',
#   'хищник',
#   'семейство',
#   'кошачий',
#   'принадлежащий',
#   'род',
#   'пантера',
#   'индеец',
#   'племя',
#   'гуарань',
#   'называть',
#   'это',
#   'животный',
#   'yaguara',
#   'зверь',
#   'убивать',
#   'один',
#   'прыжок',
#   'массивный',
#   'коренастый',
#   'тело',
#   'ягуар',
#   'достигать',
#   'длина',
#   '120',
#   '185',
#   'сантиметр',
#   'хвост',
#   'холка',
#   'среднее',
#   '6876',
#   'сантиметр',
#   'масса',
#   'колебаться',
#   '68',
#   '136',
#   'килограмм',
#   'обычно',
#   '7095',
#   'килограмм',
#   'длина',
#   'хвост',
#   'составлять',
#   '7091',
#   'сантиметр',
#   'самец',
#   'крупный',
#   'тяжёлый',
#   'самка',
#   '20',
#   'по',
#   'окрас',
#   'ягуар',
#   'похожий',
#   'леопард',
#   'чёрный',
#   'пятно',
#   'голов',
#   'лапа',
#   'живот',
#   'ягуар',
#   'сплошной',
#   'розетка',
#   'бок',
#   'выглядеть',
#   'иначе',
#   'центральный',
#   'тёмный',
#   'пятно',
#   'несколько',
#   'мелкий',
#   'пятно',
#   'окружать',
#   'кольцевой',
#   'рисунок',
#   'общий',
#   'фон',
#   'различный',
#   'оттенок',
#   'рыжий',
#   'жёлтый',
#   'цвет',
#   'живот',
#   'белый',
#   'ухо',
#   'сзади',
#   'чёрный',
#   'белые',
#   'пятно',
#   'чёрный',
#   'полоска',
#   'продолжать',
#   'угол',
#   'рот',
#   'существовать',
#   'чёрный',
#   'ягуар',
#   'меланистый',
#   'который',
#   'различить',
#   'пятнистый',
#   'рисунок',
#   'чёрный',
#   'котёнок',
#   'мочь',
#   'появиться',
#   'один',
#   'выводка',
#   'котёнок',
#   'обычный',
#   'окрас',
#   'как',
#   'леопард',
#   'пятно',
#   'точка',
#   'шкура',
#   'ягуар',
#   'расположить',
#   'индивидуально',
#   'ареал',
#   'обитание',
#   'ягуар',
#   'центральный',
#   'америка',
#   'север',
#   'аргентина',
#   'в',
#   'уругвай',
#   'сальвадор',
#   'ягуар',
#   'истребить',
#   'полностью',
#   'самый',
#   'крупный',
#   'представитель',
#   'вид',
#   'встретить',
#   'бразилия',
#   'штат',
#   'матугроса',
#   'животный',
#   'обитать',
#   'преимущественно',
#   'тропический',
#   'леса',
#   'хотя',
#   'встречаться',
#   'пампасы',
#   'район',
#   'зарасти',
#   'ксерофитный',
#   'кустарник',
#   'пустынь',
#   'полупустыня',
#   'также',
#   'морской',
#   'побережье',
#   'в',
#   'горный',
#   'область',
#   'встречаться',
#   'редко',
#   'на',
#   'данный',
#   'момент',
#   'ареал',
#   'обитание',
#   'зверь',
#   'сократиться',
#   '23',
#   'сравнение',
#   'первоначальный',
#   'юг',
#   'сша',
#   'последний',
#   'представитель',
#   'вид',
#   'убитый',
#   '1900',
#   'год',
#   'ягуар',
#   'вести',
#   'одиночный',
#   'образ',
#   'жизнь',
#   'охотиться',
#   'предпочитать',
#   'заход',
#   'солнце',
#   'рассвет',
#   'территория',
#   'один',
#   'особь',
#   '25',
#   '100',
#   'квкм',
#   'площадь',
#   'территория',
#   'обычно',
#   'вид',
#   'треугольник',
#   'зависеть',
#   'ландшафт',
#   'количество',
#   'дичь',
#   'полый',
#   'животное',
#   'самка',
#   'территория',
#   'маленький',
#   'на',
#   'определённый',
#   'участок',
#   'свой',
#   'территория',
#   'самец',
#   'обычно',
#   'охотиться',
#   '34',
#   'день',
#   'затем',
#   'менять',
#   'участок',
#   'каждый',
#   'два',
#   'неделя',
#   'зверь',
#   'проверять',
#   'пограничный',
#   'точка',
#   'не',
#   'терпеть',
#   'присутствие',
#   'свой',
#   'территория',
#   'другой',
#   'кошачий',
#   'пума',
#   'отношение',
#   'сородич',
#   'миролюбивый',
#   'поэтому',
#   'территория',
#   'ягуаровый',
#   'мочь',
#   'пересекаться',
#   'добыча',
#   'поджидать',
#   'засада',
#   'дерево',
#   'высокий',
#   'трава',
#   'недалеко',
#   'водопой',
#   'при',
#   'нападение',
#   'прыгать',
#   'жертва',
#   'спина',
#   'бок',
#   'стремиться',
#   'схватить',
#   'шея',
#   'отличие',
#   'другой',
#   'кошачий',
#   'прокусывать',
#   'жертва',
#   'череп',
#   'основный',
#   'добыча',
#   'капибара',
#   'пекарь',
#   'тапир',
#   'тп',
#   'также',
#   'птица',
#   'обезьяна',
#   'змея',
#   'грызун',
#   'охотно',
#   'нападать',
#   'домашний',
#   'скот',
#   'который',
#   'стараться',
#   'повалить',
#   'земля',
#   'убегать',
#   'животное',
#   'преследовать',
#   'на',
#   'побережье',
#   'выкапывать',
#   'черепаший',
#   'яйцо',
#   'также',
#   'расправляться',
#   'черепаха',
#   'добывать',
#   'мягкий',
#   'часть',
#   'рептилия',
#   'лапа',
#   'передний',
#   'отверстие',
#   'некрупный',
#   'особь',
#   'раздавить',
#   'зуб',
#   'этот',
#   'зверь',
#   'отличный',
#   'рыбак',
#   'хороший',
#   'пловец',
#   'добыча',
#   'поедать',
#   'голов',
#   'если',
#   'велик',
#   'утолять',
#   'голод',
#   '2',
#   'приём',
#   'интервал',
#   '10',
#   '12',
#   'часы',
#   'падаль',
#   'практически',
#   'питаться',
#   'охотиться',
#   'ягуар',
#   'отрывисто',
#   'гортанно',
#   'ворчать',
#   'брачный',
#   'период',
#   'ночь',
#   'громко',
#   'ревета',
#   'сезонность',
#   'размножение',
#   'тропик',
#   'выразить',
#   'область',
#   'дождливый',
#   'сезон',
#   'пик',
#   'рождаемость',
#   'приходиться',
#   'дождливый',
#   'период',
#   'в',
#   'брачный',
#   'период',
#   'ягуар',
#   'мочь',
#   'собираться',
#   'группа',
#   'иногда',
#   'наблюдаться',
#   'драка',
#   'самец',
#   'выбор',
#   'партнёр',
#   'зависеть',
#   'самка',
#   'переходящий',
#   'территория',
#   'избранник',
#   'после',
#   'спаривание',
#   'самец',
#   'покидать',
#   'самка',
#   'через',
#   '100',
#   '110',
#   'день',
#   'густой',
#   'кустарник',
#   'логово',
#   'среди',
#   'камень',
#   'появляться',
#   '1',
#   '4',
#   'слепой',
#   'глухой',
#   'котёнок',
#   'через',
#   '6',
#   'неделя',
#   'малыш',
#   'начинать',
#   'охотиться',
#   'матерь',
#   'оставаться',
#   'около',
#   '2',
#   'год',
#   'пока',
#   'обрести',
#   'свой',
#   'участок',
#   'половый',
#   'зрелость',
#   'наступать',
#   '3',
#   'год',
#   'срок',
#   'жизнь',
#   'природа',
#   'мало',
#   'изучить',
#   'неволя',
#   'ягуар',
#   'доживать',
#   '25',
#   'год',
#   'несмотря',
#   'человек',
#   'ягуар',
#   'нападать',
#   'крайне',
#   'редко',
#   'значительный',
#   'часть',
#   'ареал',
#   'практически',
#   'истребить',
#   'изз',
#   'ценный',
#   'мех',
#   'не',
#   'последний',
#   'роль',
#   'истребление',
#   'животное',
#   'играть',
#   'скотовод',
#   'опасаться',
#   'свой',
#   'стадо',
#   'в',
#   'настоящее',
#   'время',
#   'ягуар',
#   'внести',
#   'красный',
#   'книга',
#   'однако',
#   'бразилия',
#   'мексика',
#   'боливия',
#   'охота',
#   'это',
#   'животный',
#   'разрешить'],
#  ['название',
#   'название',
#   'ягуар',
#   'предположительно',
#   'произойти',
#   'слово',
#   'yaguara',
#   'jaguarete',
#   'означать',
#   'зверь',
#   'убивать',
#   'один',
#   'прыжок',
#   'некоторый',
#   'племя',
#   'индеец',
#   'амазонии',
#   'называть',
#   'ягуар',
#   'iawa',
#   'panthera',
#   'латинский',
#   'переводиться',
#   'ловец',
#   'колючка',
#   'шип',
#   'подразумеваться',
#   'мощный',
#   'когтить',
#   'ягуар',
#   'ареал',
#   'северный',
#   'южный',
#   'америка',
#   'юг',
#   'мексика',
#   'бразилия',
#   'аргентина',
#   'костарик',
#   'парагвай',
#   'панама',
#   'сальвадор',
#   'уругвай',
#   'гватемала',
#   'перу',
#   'колумбия',
#   'боливия',
#   'венесуэла',
#   'суринам',
#   'французский',
#   'гвиана',
#   'описание',
#   'самый',
#   'крупный',
#   'дикий',
#   'кошка',
#   'новое',
#   'свет',
#   'внешне',
#   'ягуар',
#   'очень',
#   'похожий',
#   'леопард',
#   'крупный',
#   'тяжёлый',
#   'голова',
#   'крупный',
#   'конечность',
#   'короткий',
#   'мощный',
#   'изз',
#   'ягуар',
#   'выглядеть',
#   'приземистый',
#   'строение',
#   'череп',
#   'ягуар',
#   'близкий',
#   'тигр',
#   'леопард',
#   'зато',
#   'окрасить',
#   'последний',
#   'ухо',
#   'закруглить',
#   'мех',
#   'густой',
#   'короткий',
#   'самка',
#   '20',
#   'весить',
#   'маленький',
#   'самец',
#   'окрас',
#   'основной',
#   'окрас',
#   'тело',
#   'песочный',
#   'яркорыжеть',
#   'охра',
#   'низ',
#   'горло',
#   'живот',
#   'внутренний',
#   'сторона',
#   'лапа',
#   'белый',
#   'по',
#   'туловище',
#   'разбросать',
#   'пятно',
#   'сплошной',
#   'кольцо',
#   'розетка',
#   'тёмный',
#   'общий',
#   'фон',
#   'тело',
#   'на',
#   'голов',
#   'лапа',
#   'чёрный',
#   'крап',
#   'на',
#   'хвост',
#   'заметный',
#   'узор',
#   'кольцевой',
#   'пятно',
#   'розетка',
#   'внутри',
#   'шерсть',
#   'светлый',
#   'ухо',
#   'снаружи',
#   'чёрный',
#   'посередине',
#   'жёлтый',
#   'пятно',
#   'встречаться',
#   'полностью',
#   'чёрный',
#   'особь',
#   'внешне',
#   'похожий',
#   'пантера',
#   'размер',
#   'длина',
#   'тело',
#   '150180',
#   'сантиметр',
#   'хвост',
#   '7091',
#   'сантиметр',
#   'высота',
#   'холка',
#   '5176',
#   'сантиметр',
#   'вес',
#   '56150',
#   'килограмм',
#   'среднее',
#   '100',
#   'килограмм',
#   'продолжительность',
#   'жизнь',
#   'природа',
#   '10',
#   'год',
#   'неволя',
#   '25',
#   'год',
#   'неволя',
#   'мочь',
#   'рычать',
#   'подобно',
#   'лев',
#   'также',
#   'урчать',
#   'мурлыкать',
#   'голос',
#   'ягуар',
#   'напоминать',
#   'сиплый',
#   'лающий',
#   'кашель',
#   'звук',
#   'распиливать',
#   'дерево',
#   'среда',
#   'обитание',
#   'занимать',
#   'различный',
#   'место',
#   'обитание',
#   'густой',
#   'непроходимый',
#   'леса',
#   'редколесье',
#   'степь',
#   'прибрежный',
#   'роща',
#   'заросль',
#   'тростник',
#   'предпочитать',
#   'равнинный',
#   'тропический',
#   'дождевой',
#   'леса',
#   'повышенный',
#   'влажность',
#   'открытый',
#   'равнина',
#   'покрыть',
#   'трава',
#   'избегать',
#   'любить',
#   'вода',
#   'время',
#   'проводить',
#   'водоём',
#   'пища',
#   'рацион',
#   'ягуар',
#   'довольно',
#   'разнообразный',
#   'мелкий',
#   'крупный',
#   'позвоночный',
#   'птица',
#   'рептилия',
#   'кайман',
#   'аллигатор',
#   'морской',
#   'черепаха',
#   'крупный',
#   'грызун',
#   'капибара',
#   'рыба',
#   'примат',
#   'дикий',
#   'свинья',
#   'амфибия',
#   'олень',
#   'поведение',
#   'ягуар',
#   'активный',
#   'любой',
#   'время',
#   'сутки',
#   'обычно',
#   'выходить',
#   'охота',
#   'сумерки',
#   'лунный',
#   'ночь',
#   'хорошо',
#   'ловко',
#   'лазать',
#   'дерево',
#   'предпочитать',
#   'передвигаться',
#   'земля',
#   'любить',
#   'вода',
#   'возможность',
#   'проводить',
#   'время',
#   'отлично',
#   'плавать',
#   'чаща',
#   'ягуар',
#   'охотиться',
#   'засада',
#   'который',
#   'устраивать',
#   'берег',
#   'водоём',
#   'высокий',
#   'трава',
#   'дерево',
#   'тропинка',
#   'ведущий',
#   'водопой',
#   'нападать',
#   'жертва',
#   'прыгать',
#   'спин',
#   'пытаться',
#   'повалить',
#   'хватать',
#   'жертва',
#   'шея',
#   'укус',
#   'ягуар',
#   'настолько',
#   'сильный',
#   'способный',
#   'прокусить',
#   'корова',
#   'череп',
#   'ягуар',
#   'способный',
#   'справиться',
#   'добить',
#   'который',
#   'весить',
#   '300',
#   'килограмм',
#   'на',
#   'рыба',
#   'охотиться',
#   'берег',
#   'вышвыривать',
#   'вода',
#   'удар',
#   'мощный',
#   'лапа',
#   'за',
#   'обезьяна',
#   'охотиться',
#   'дерево',
#   'либо',
#   'около',
#   'водопой',
#   'никогда',
#   'преследовать',
#   'жертва',
#   'начинать',
#   'убегать',
#   'добыча',
#   'начинать',
#   'поедать',
#   'голов',
#   'постепенно',
#   'продвигаться',
#   'задний',
#   'часть',
#   'если',
#   'добыча',
#   'крупный',
#   'ягуар',
#   'оставаться',
#   'около',
#   'некоторый',
#   'время',
#   'падаль',
#   'питаться',
#   'социальный',
#   'структура',
#   'вне',
#   'сезон',
#   'размножение',
#   'ягуар',
#   'вести',
#   'одиночный',
#   'образ',
#   'жизнь',
#   'территориальный',
#   'площадь',
#   'участок',
#   'занимать',
#   '25170',
#   'км2',
#   'размер',
#   'охотничий',
#   'участок',
#   'зависеть',
#   'ландшафт',
#   'обилие',
#   'добыча',
#   'полый',
#   'на',
#   'один',
#   'участок',
#   'предел',
#   'свой',
#   'территория',
#   'самец',
#   'держаться',
#   '34',
#   'день',
#   'идти',
#   'далёкий',
#   'крайне',
#   'нетерпимый',
#   'другой',
#   'представитель',
#   'семейство',
#   'кошачий',
#   'например',
#   'пума',
#   'время',
#   'миролюбивый',
#   'подобный',
#   'охотничий',
#   'участок',
#   'ягуаровый',
#   'часто',
#   'пересекаться',
#   'себя',
#   'размножение',
#   'наступить',
#   'эструс',
#   'самка',
#   'оповещать',
#   'самец',
#   'оставлять',
#   'дерево',
#   'метка',
#   'мочить',
#   'в',
#   'период',
#   'свадьба',
#   'ягуар',
#   'собираться',
#   'небольшой',
#   'группа',
#   'поединок',
#   'самец',
#   'отсутствовать',
#   'тк',
#   'выбор',
#   'партнёр',
#   'полностью',
#   'зависеть',
#   'самый',
#   'самка',
#   'после',
#   'свой',
#   'выбор',
#   'переходить',
#   'территория',
#   'самец',
#   'оставаться',
#   'несколько',
#   'день',
#   'нередко',
#   'один',
#   'самка',
#   'спариваться',
#   'несколько',
#   'самец',
#   'для',
#   'логово',
#   'самка',
#   'выбирать',
#   'место',
#   'среди',
#   'камень',
#   'заросль',
#   'кустарник',
#   'дупло',
#   'дерево',
#   'у',
#   'самка',
#   'наступать',
#   'эструс',
#   'тот',
#   'пора',
#   'пока',
#   'оставаться',
#   'детёныш',
#   'сезонпериод',
#   'размножение',
#   'течение',
#   'год',
#   'половый',
#   'созревание',
#   'самка',
#   '23',
#   'год',
#   'самец',
#   '34',
#   'год',
#   'беременность',
#   '93110',
#   'день',
#   'потомство',
#   'помета',
#   '14',
#   'пятнистый',
#   'котёнок',
#   'выходить',
#   'логово',
#   'детёныш',
#   'начинать',
#   '15',
#   'мес',
#   'возраст',
#   'в',
#   'возраст',
#   'мать',
#   'начинать',
#   'брать',
#   'себя',
#   'охота',
#   'смертность',
#   'среди',
#   'котёнок',
#   'высокий',
#   'два',
#   'год',
#   'доживать',
#   '50',
#   'молодая',
#   'ягуаровый',
#   'детёныш',
#   'жить',
#   'матерь',
#   'год',
#   'затем',
#   'начинать',
#   'начинать',
#   'самостоятельный',
#   'жизнь',
#   'пользавред',
#   'человек',
#   'ягуар',
#   'опасный',
#   'человек',
#   'чаща',
#   'нападать',
#   'время',
#   'защита',
#   'есть',
#   'сведение',
#   'встреча',
#   'негр',
#   'белых',
#   'предпочитать',
#   'нападать',
#   'один',
#   'легко',
#   'переносить',
#   'неволить',
#   'размножаться',
#   'зоопарк',
#   'нападать',
#   'домашний',
#   'скот',
#   'изз',
#   'активно',
#   'преследоваться',
#   'фермер',
#   'на',
#   'ягуаровый',
#   'вестись',
#   'охота',
#   'изз',
#   'красивый',
#   'мех',
#   'популяциястатус',
#   'сохранение',
#   'больший',
#   'часть',
#   'ареал',
#   'ягуар',
#   'полностью',
#   'истребить',
#   'основный',
#   'угроза',
#   'вид',
#   'браконьерский',
#   'охота',
#   'сокращение',
#   'место',
#   'обитание',
#   'вид',
#   'внести',
#   'международный',
#   'красный',
#   'книга',
#   'мсопа',
#   'в',
#   'настоящее',
#   'время',
#   'признать',
#   '9',
#   'подвид',
#   'panthera',
#   'который',
#   'отличаться',
#   'размер',
#   'окрас',
#   'узор',
#   'тело',
#   'p',
#   'o',
#   'амазония',
#   'p',
#   'o',
#   'arizonensis',
#   'мексика',
#   'p',
#   'o',
#   'centralis',
#   'центральный',
#   'америка',
#   'p',
#   'o',
#   'goldmani',
#   'мексика',
#   'белиз',
#   'p',
#   'o',
#   'hernandesii',
#   'мексика',
#   'p',
#   'o',
#   'palustris',
#   'южный',
#   'бразилия',
#   'p',
#   'o',
#   'paraguensis',
#   'парагвай',
#   'p',
#   'o',
#   'peruvianus',
#   'перу',
#   'эквадор',
#   'p',
#   'o',
#   'veracrucis',
#   'техас',
#   '2',
#   'миллион',
#   'год',
#   'назад',
#   'ягуар',
#   'населять',
#   'весь',
#   'юг',
#   'нынешний',
#   'сша',
#   'в',
#   'настоящее',
#   'время',
#   'ареал',
#   'вид',
#   'сократиться',
#   'треть',
#   'первоначальный',
#   'скрещиваться',
#   'леопард',
#   'пантера',
#   'производить',
#   'помесь',
#   'способный',
#   'дальнейший',
#   'продолжение',
#   'род'],
#  ['ягуар',
#   'относиться',
#   'один',
#   'самый',
#   'крупный',
#   'животное',
#   'семейство',
#   'кошачий',
#   'также',
#   'единственный',
#   'животный',
#   'который',
#   'представлять',
#   'род',
#   'пантера',
#   'америка',
#   'после',
#   'тигр',
#   'лев',
#   'ягуар',
#   'считаться',
#   'три',
#   'животный',
#   'величина',
#   'семейство',
#   'кошачий',
#   'этот',
#   'зверь',
#   'обладать',
#   'один',
#   'мощный',
#   'челюсть',
#   'пропорция',
#   'размер',
#   'голов',
#   'среди',
#   'существующий',
#   'кошка',
#   'вес',
#   'самец',
#   'ягуар',
#   'колебаться',
#   'предел',
#   '90',
#   '120',
#   'килограмм',
#   'самка',
#   'животное',
#   'правило',
#   'весить',
#   '90',
#   'килограмм',
#   'менее',
#   '60кг',
#   'ягуар',
#   'превосходно',
#   'чувствовать',
#   'самый',
#   'различный',
#   'тропический',
#   'среда',
#   'они',
#   'приспособить',
#   'жизнь',
#   'горный',
#   'леса',
#   'влажный',
#   'саванна',
#   'также',
#   'мочь',
#   'проживать',
#   'тропический',
#   'джунгли',
#   'наиболее',
#   'крупный',
#   'ягуар',
#   'обитать',
#   'саванна',
#   'лесной',
#   'зона',
#   'размер',
#   'этот',
#   'дикий',
#   'кошка',
#   'гораздо',
#   'маленький',
#   'не',
#   'смотреть',
#   'ягуар',
#   'мочь',
#   'обитать',
#   'многий',
#   'территориальный',
#   'местность',
#   'отдавать',
#   'предпочтение',
#   'густой',
#   'леса',
#   'расположить',
#   'низина',
#   'повышенный',
#   'уровень',
#   'влажность',
#   'сырость',
#   'этот',
#   'животное',
#   'стараться',
#   'избегать',
#   'сухой',
#   'лес',
#   'открытый',
#   'поляна',
#   'встретить',
#   'ягуаровый',
#   'тропический',
#   'леса',
#   'америка',
#   'южный',
#   'бразилия',
#   'мексика',
#   'юг',
#   'уругвай',
#   'аргентина',
#   'перу',
#   'боливия',
#   'колумбия',
#   'также',
#   'встречаться',
#   'данный',
#   'животный',
#   'уругвай',
#   'панама',
#   'венесуэла',
#   'территория',
#   'северный',
#   'америка',
#   'техас',
#   'аризона',
#   'юг',
#   'калифорния',
#   'ягуар',
#   'довольно',
#   'мускулистый',
#   'животное',
#   'иметь',
#   'короткий',
#   'конечность',
#   'если',
#   'сравнивать',
#   'ягуар',
#   'леопард',
#   'последний',
#   'существенно',
#   'уступать',
#   'размер',
#   'ягуар',
#   'голова',
#   'ягуар',
#   'широкий',
#   'тяжёлый',
#   'тело',
#   'гибкий',
#   'подвижный',
#   'животный',
#   'обладать',
#   'удивительно',
#   'красивый',
#   'расцветка',
#   'задний',
#   'фон',
#   'животное',
#   'темно',
#   'жёлтый',
#   'область',
#   'живот',
#   'горло',
#   'тон',
#   'светлеть',
#   'голова',
#   'шея',
#   'дать',
#   'дикий',
#   'кошка',
#   'укрытый',
#   'отдельный',
#   'чёрный',
#   'пятно',
#   'благодаря',
#   'что',
#   'схожий',
#   'леопард',
#   'спин',
#   'ягуаровый',
#   'также',
#   'укрытый',
#   'такой',
#   'пятно',
#   'который',
#   'довольно',
#   'часто',
#   'образовать',
#   'целовать',
#   'линия',
#   'рацион',
#   'питание',
#   'ягуаровый',
#   'зависеть',
#   'место',
#   'обитание',
#   'в',
#   'мексика',
#   'вести',
#   'охота',
#   'дикий',
#   'свиной',
#   'выслеживать',
#   'отстать',
#   'стадо',
#   'жертва',
#   'нападать',
#   'она',
#   'довольно',
#   'часто',
#   'качество',
#   'жертва',
#   'ягуар',
#   'избирать',
#   'олень',
#   'лошадь',
#   'крупный',
#   'рогатый',
#   'скот',
#   'также',
#   'рацион',
#   'этот',
#   'дикий',
#   'кошка',
#   'мочь',
#   'входить',
#   'яйцо',
#   'морской',
#   'черепаха',
#   'который',
#   'являться',
#   'ягуаровый',
#   'излюбить',
#   'лакомство',
#   'средний',
#   'продолжительность',
#   'жизнь',
#   'ягуаровый',
#   'достигать',
#   '22',
#   'год'],
#  ['один',
#   'крупный',
#   'хищный',
#   'млекопитающее',
#   'семейство',
#   'кошачий',
#   'принадлежащий',
#   'род',
#   'пантера',
#   'ягуар',
#   'представлять',
#   'себя',
#   'крупный',
#   'животный',
#   'мускулистый',
#   'тело',
#   'голова',
#   'округлый',
#   'форма',
#   'густой',
#   'короткий',
#   'шерсть',
#   'длинный',
#   'хвост',
#   'весь',
#   'вид',
#   'ягуаровый',
#   'иметь',
#   'характерный',
#   'раскраска',
#   'состоять',
#   'грязно',
#   'жёлтый',
#   'фон',
#   'чёрный',
#   'сплошной',
#   'кольцеобразный',
#   'пятно',
#   'распределенный',
#   'весь',
#   'тело',
#   'встретить',
#   'ягуар',
#   'густой',
#   'тропический',
#   'леса',
#   'высоко',
#   'гора',
#   'океанский',
#   'побережье',
#   'нередко',
#   'заниматься',
#   'выкапывание',
#   'черепаший',
#   'яйцо'],
#  ['в',
#   'влажный',
#   'тропический',
#   'леса',
#   'центральный',
#   'южный',
#   'америка',
#   'проживать',
#   'красивый',
#   'пятнистый',
#   'животный',
#   'семейство',
#   'кошачий',
#   'ягуар',
#   'мех',
#   'животное',
#   'густой',
#   'окрас',
#   'варьироваться',
#   'светложёлтый',
#   'огненнорыжий',
#   'тело',
#   'покрыть',
#   'чёрный',
#   'пятно',
#   'вид',
#   'кольцо',
#   'середина',
#   'который',
#   'расположить',
#   'точка',
#   'чёрный',
#   'цвет',
#   'грудь',
#   'живот',
#   'полосатый',
#   'лапа',
#   'мощный',
#   'большой',
#   'чёрный',
#   'крапинка'],
#  ['ягуар',
#   'крупный',
#   'хищник',
#   'южный',
#   'америка',
#   'этот',
#   'огромный',
#   'кошка',
#   'жить',
#   'поодиночке',
#   'пара',
#   'маленький',
#   'семья',
#   'они',
#   'обходить',
#   'территория',
#   '830',
#   'км2ть',
#   'мировой',
#   'классификация',
#   'занимать',
#   'третье',
#   'место',
#   'среди',
#   'кошачий',
#   'уступать',
#   'вес',
#   'лев',
#   'тигр'],
#  ['ягуар',
#   'млекопитающее',
#   'семейство',
#   'кошачий',
#   'свой',
#   'название',
#   'получить',
#   'индеец',
#   'гуарань',
#   'который',
#   'называть',
#   'ягуаретта',
#   'собачий',
#   'тело',
#   'в',
#   'весь',
#   'фигура',
#   'выражаться',
#   'сила',
#   'ловкость',
#   'кажется',
#   'несколько',
#   'тяжеловатый',
#   'ход',
#   'туловище',
#   'ягуар',
#   'длинно',
#   'леопард',
#   'тигр',
#   'конечность',
#   'сравнительно',
#   'тело',
#   'короче',
#   'этот',
#   'кошка',
#   'вполне',
#   'взрослый',
#   'ягуар',
#   'иметь',
#   'около',
#   '145',
#   'сантиметр',
#   'общий',
#   'длина',
#   '68',
#   'сантиметр',
#   'приходиться',
#   'хвост',
#   'мех',
#   'густой',
#   'короткий',
#   'блестящий',
#   'мягкий',
#   'горло',
#   'нижний',
#   'часть',
#   'шея',
#   'грудь',
#   'живот',
#   'длинный',
#   'остальной',
#   'тело',
#   'у',
#   'больший',
#   'особый',
#   'шерсть',
#   'красноватожёлтый',
#   'исключение',
#   'внутренность',
#   'уха',
#   'нижний',
#   'часть',
#   'лицо',
#   'челюсть',
#   'горло',
#   'вообще',
#   'нижний',
#   'часть',
#   'тело',
#   'внутренний',
#   'сторона',
#   'нога',
#   'преобладать',
#   'белый',
#   'цвета',
#   'весь',
#   'мех',
#   'покрыть',
#   'частью',
#   'небольшой',
#   'чёрный',
#   'круглый',
#   'продолговатый',
#   'неправильный',
#   'пятно',
#   'частью',
#   'больший',
#   'пятно',
#   'кольцо',
#   'который',
#   'окаймить',
#   'желтоватокрасный',
#   'чёрный',
#   'полоска',
#   'иметь',
#   'посредине',
#   'один',
#   'чёрный',
#   'пятно',
#   'обитать',
#   'главное',
#   'образ',
#   'тропический',
#   'субтропический',
#   'леса',
#   'америка'],
#  ['большой',
#   'грациозный',
#   'кошка',
#   'ягуар',
#   'обитать',
#   'исключительно',
#   'территория',
#   'америка',
#   'в',
#   'сша',
#   'уругвай',
#   'сальвадор',
#   'хитрый',
#   'коварный',
#   'хищник',
#   'практически',
#   'полностью',
#   'истребить',
#   'скотовод',
#   'опасаться',
#   'свой',
#   'стадо',
#   'охотник',
#   'ценный',
#   'мех'],
#  ['jaguar',
#   'напиток',
#   'jaguar',
#   'слабоалкогольный',
#   'газировать',
#   'энергетический',
#   'напиток',
#   'алюминиевый',
#   'банка',
#   'напиток',
#   '033',
#   'литр',
#   '9',
#   'алюминиевый',
#   'банка',
#   'напиток',
#   '033',
#   'литр',
#   '9',
#   'основатель',
#   'ibb',
#   'ltd',
#   'крепость',
#   '559',
#   'состояние',
#   'выпускаться',
#   'период',
#   'c',
#   '16',
#   'мартаисточник',
#   'указанный',
#   '699',
#   'день',
#   '2003',
#   'год',
#   'тип',
#   'слабоалкогольный',
#   'газировать',
#   'энергетический',
#   'напиток',
#   'сайт',
#   'jaguardrinkcom',
#   'jaguar',
#   'русый',
#   'ягуар',
#   'сленг',
#   'яга',
#   'слабоалкогольный',
#   'газировать',
#   'энергетический',
#   'напиток',
#   'содержание',
#   'объём',
#   'этиловый',
#   'спирт',
#   '7',
#   'ранее',
#   'выпускаться',
#   'также',
#   '9',
#   '55',
#   'выпускаться',
#   'россия',
#   '2003',
#   'год',
#   'компания',
#   'happyland',
#   'эксклюзивный',
#   'право',
#   'производство',
#   'реализация',
#   'принадлежать',
#   'зарегистрировать',
#   'великобритания',
#   'компания',
#   'ibb',
#   'ltd',
#   'состав',
#   'состав',
#   'порядок',
#   'убывание',
#   'масса',
#   'компонент',
#   'вод',
#   'сахар',
#   'спирт',
#   'этиловый',
#   'лимонный',
#   'кислота',
#   'экстракт',
#   'лист',
#   'мат',
#   'таурина',
#   'кофеин',
#   'краситель',
#   'карамель',
#   'антоцианин',
#   'кармин',
#   'натуральный',
#   'ароматизатор',
#   'терпкость',
#   'различный',
#   'витамин',
#   '100',
#   'мл',
#   'напиток',
#   'содержимый',
#   'углевод',
#   '115',
#   'год',
#   'кофеин',
#   '30',
#   'мг',
#   'таурина',
#   '40',
#   'мг',
#   'витамин',
#   'b1',
#   'b6',
#   'pp',
#   '011',
#   'мг',
#   'энергетический',
#   'ценность',
#   '1004',
#   'ккал',
#   'производство',
#   'в',
#   'россия',
#   'ягуар',
#   'разливаться',
#   'четыре',
#   'заводахисточник',
#   'указанный',
#   '807',
#   'день',
#   'ооо',
#   'юнайтед',
#   'ботлинга',
#   'группа',
#   '170039',
#   'год',
#   'тверь',
#   'ооо',
#   'мегапак',
#   '142700',
#   'московский',
#   'область',
#   'ленинский',
#   'рн',
#   'год',
#   'видный',
#   'зао',
#   'остаква',
#   '142432',
#   'московский',
#   'область',
#   'ногинский',
#   'рн',
#   'год',
#   'черноголовка',
#   'ооо',
#   'артисан',
#   '353240',
#   'краснодарский',
#   'край',
#   'северский',
#   'рн',
#   'станица',
#   'северский',
#   'в',
#   'март',
#   '2007',
#   'год',
#   'начать',
#   'выпуск',
#   'напиток',
#   'jaguar',
#   'light',
#   'пониженный',
#   'содержание',
#   'алкоголь',
#   '55',
#   'отсутствие',
#   'таурина',
#   'состав',
#   'банка',
#   'это',
#   'напиток',
#   'иметь',
#   'белый',
#   'цвета',
#   'противоположность',
#   'тёмный',
#   'цвета',
#   'классический',
#   'напиток',
#   'поздний',
#   'jaguar',
#   'light',
#   'заменить',
#   'напиток',
#   'jaguar',
#   'ultra',
#   'light',
#   'содержание',
#   'алкоголь',
#   '7',
#   'пониженный',
#   'содержание',
#   'калория',
#   'в',
#   'август',
#   '2010',
#   'год',
#   'украина',
#   'напиток',
#   'начать',
#   'экспортироваться',
#   'бренд',
#   'jaguaro',
#   'крепость',
#   '7',
#   'цвета',
#   'банка',
#   'соответствовать',
#   'оригинальный',
#   'несколько',
#   'изменить',
#   'пропорция',
#   'в',
#   '2011',
#   'год',
#   'напиток',
#   'крепость',
#   '7',
#   'появиться',
#   'россия',
#   'постепенно',
#   'заменить',
#   'себя',
#   'девятиградусный',
#   'однако',
#   'десятилетие',
#   'торговый',
#   'марка',
#   'также',
#   'осуществлна',
#   'выпуск',
#   'оригинальный',
#   'девятиградусный',
#   'напиток',
#   'ограниченный',
#   'тираж',
#   'в',
#   '2011',
#   'год',
#   'начать',
#   'выпуск',
#   'новое',
#   'напиток',
#   'jaguar',
#   'gold',
#   'объёмный',
#   'содержание',
#   'этанол',
#   '7',
#   'однако',
#   'обладать',
#   'цитрусовый',
#   'вкус',
#   'содержимый',
#   'апельсиновый',
#   'сок',
#   'объёмный',
#   'доля',
#   '10',
#   'отражение',
#   'искусство',
#   'рэпер',
#   'сява',
#   'посвятить',
#   'это',
#   'напиток',
#   'песня',
#   'ягуар',
#   'noize',
#   'mc',
#   'написать',
#   'песня',
#   'мотив',
#   'word',
#   'up',
#   'выступить',
#   'фестиваль',
#   'jaga',
#   'fest',
#   'который',
#   'проходить',
#   'поддержка',
#   'напиток',
#   'в',
#   'песня',
#   'ягуар',
#   'сравниваться',
#   'героиномносить',
#   'колоссальный',
#   'вред',
#   'сердце',
#   'повышаться',
#   'артериальный',
#   'давление',
#   'увеличиваться',
#   'пульс',
#   'сердце',
#   'начинать',
#   'работать',
#   'износ',
#   'сердце',
#   'делать',
#   'среднее',
#   '10000',
#   '15000',
#   'лишний',
#   'сокращение',
#   'печень',
#   'напиток',
#   'ягуар',
#   'серьёзно',
#   'вредить',
#   'печень',
#   'печень',
#   'вынудить',
#   'перерабатывать',
#   'алкоголь',
#   'химия',
#   'постепенно',
#   'энергетический',
#   'запас',
#   'печень',
#   'значительно',
#   'снижаться',
#   'не',
#   'редкий',
#   'случай',
#   'аллергический',
#   'реакция',
#   'напиток',
#   'ягуар',
#   'собрать',
#   'большой',
#   'количество',
#   'разнообразный',
#   'химический',
#   'вещество',
#   'любой',
#   'этот',
#   'вещество',
#   'вызвать',
#   'анафилактический',
#   'шок',
#   'смерть',
#   'который',
#   'практически',
#   'моментальный',
#   'ряд',
#   'специализировать',
#   'бригада',
#   'такой',
#   'случай',
#   'иметь',
#   'место',
#   'вред',
#   'напиток',
#   'ягуарсредний',
#   'возраст',
#   'потребитель',
#   'дать',
#   'напиток',
#   '1216',
#   'год',
#   'дать',
#   'напиток',
#   'способствовать',
#   'ранний',
#   'регулярный',
#   'потребление',
#   'алкоголь',
#   'приводить',
#   'развитие',
#   'детский',
#   'юношеский',
#   'алкоголизм',
#   'производитель',
#   'дать',
#   'напиток',
#   'многий',
#   'договаривать',
#   'ограничиваться',
#   'надпись',
#   'рекомендоваться',
#   'выпивать',
#   '1',
#   'банка',
#   'день',
#   'больной',
#   'беременный',
#   'однако',
#   'подросток',
#   'ограничиваться',
#   '1ой',
#   'банка',
#   'ягуар',
#   'среднее',
#   'потреблять',
#   '23',
#   'дискотека',
#   '810',
#   'банка',
#   'ночь',
#   'редкость',
#   'вред',
#   'напиток',
#   'ягуар',
#   'подобный',
#   'очевидный',
#   'главный',
#   'санитарный',
#   'врач',
#   'год',
#   'онищенко',
#   'обеспокоить',
#   'возрасти',
#   'процент',
#   'ранний',
#   'регулярный',
#   'потребление',
#   'алкоголь',
#   'вопрос',
#   'запрещение',
#   'подобный',
#   'напиток',
#   'подниматься',
#   'дума',
#   'очень',
#   'серьёзно',
#   'мешать',
#   'алкогольный',
#   'лобби',
#   'слово',
#   'гонищенко',
#   'здравомыслящий',
#   'человек',
#   'дума',
#   'очень',
#   'мало',
#   'основное',
#   'сидеть',
#   'человек',
#   'который',
#   'решать',
#   'вопрос',
#   'бизнес',
#   'обычный',
#   'гражданин',
#   'а',
#   'вы',
#   'красиво',
#   'выступать',
#   'телевидение',
#   'обзывать',
#   'свой',
#   'конкурент',
#   'падонка',
#   'что',
#   'решаться',
#   'закрытый',
#   'дверь',
#   'какой',
#   'вопрос',
#   'ставиться',
#   'голосовать',
#   'наш',
#   'избранный',
#   'слуга',
#   'народ',
#   'мы',
#   'известно',
#   'нет',
#   'закон',
#   'давать',
#   'право',
#   'узнать',
#   'гражданин',
#   'голосовать',
#   'избранный',
#   'народ',
#   'депутат',
#   'единственный',
#   'это',
#   'сделать',
#   'это',
#   'депутат',
#   'соответствующий',
#   'запрос',
#   'мы',
#   'жить',
#   'неведение',
#   'какой',
#   'закон',
#   'приниматься',
#   'что',
#   'мочь',
#   'сделать',
#   'это',
#   'активный',
#   'жизненный',
#   'позиция',
#   'данные',
#   'вопрос',
#   'нужно',
#   'помочь',
#   'нормальный',
#   'чиновник',
#   'запретить',
#   'дать',
#   'напиток',
#   'осознать',
#   'вред',
#   'напиток',
#   'тип',
#   'ягуар',
#   'вести',
#   'пропаганда',
#   'активный',
#   'разъяснительный',
#   'беседа',
#   'подрастать',
#   'гражданин',
#   'наш',
#   'родина',
#   'искоренить',
#   'безучастность',
#   'проблема',
#   'родина',
#   'запомнить',
#   'энергетический',
#   'напиток',
#   'энергия',
#   'содержимый',
#   'давать',
#   'энергия',
#   'человек',
#   'многие',
#   'считать',
#   'мобилизовать',
#   'трата',
#   'собственный',
#   'энергия',
#   'который',
#   'организм',
#   'накопить',
#   'так',
#   'человек',
#   'истощать'],
#  ['слабоалкогольный',
#   'напиток',
#   'ягуар',
#   'самый',
#   'популярный',
#   'напиток',
#   'среди',
#   'молодёжь',
#   'проходить',
#   'мимо',
#   'парковый',
#   'скверик',
#   'пр',
#   'часто',
#   'замечать',
#   'школьник',
#   'молодая',
#   'человек',
#   'пить',
#   'напиток',
#   'ягуар',
#   'очень',
#   'полюбить',
#   'девушка',
#   'давать',
#   'разобраться',
#   'представлять',
#   'напиток',
#   'вред',
#   'ягуар',
#   'в',
#   'напиток',
#   'ягуар',
#   'содержаться',
#   '9',
#   'спирт',
#   'равно',
#   '50',
#   'гр',
#   'водка',
#   'мнение',
# ...
#   'стежок',
#   'строчка',
#   'получаться',
#   'разный',
#   'в',
#   'случай',
#   'требоваться',
#   'небольшой',
#   'регулировка',
#   'оверлочный',
#   'строчка',
#   'применение',
#   'найти',
#   'бестолковый',
#   'на',
#   'взгляд',
#   'шить',
#   'самый',
#   'простой',
#   'вещий',
#   'необходимый',
#   'полноценный',
#   'оверлок',
#   'машинка',
#   'очень',
#   'шить',
#   'трикотажный',
#   'ткань',
#   'рвать',
#   'шифон',
#   'джинс',
#   'прошивать',
#   'max',
#   '3',
#   'слой',
#   'драп',
#   '2',
#   'реверс',
#   'немного',
#   'туговатый',
#   'кнопка',
#   'обязательно',
#   'нужно',
#   'держать',
#   'один',
#   'рука',
#   'это',
#   'очень',
#   'неудобно',
#   'на',
#   'швейный',
#   'машинка',
#   'jaguar',
#   '333',
#   'удобно',
#   'легко',
#   'вшивать',
#   'молния',
#   'для',
#   'вышивание',
#   'петля',
#   'необходимый',
#   'сноровка',
#   'какоеть',
#   'время',
#   'начинать',
#   'получаться',
#   'довольно',
#   'плохо',
#   'в',
#   'целое',
#   'швейный',
#   'машинка',
#   'jaguar',
#   '333',
#   'очень',
#   'довольный',
#   'думать',
#   '4000',
#   'рубль',
#   'это',
#   'отличный',
#   'приобретение',
#   'папа',
#   'огромный',
#   'спасибо',
#   'шить',
#   'чинить',
#   'вещий',
#   'стать',
#   'быстрый',
#   'простой'],
#  ['швейный',
#   'машинка',
#   'дом',
#   'ягуар',
#   'хороший',
#   'модель',
#   'у',
#   'каждый',
#   'хозяйка',
#   'рука',
#   'должный',
#   'такой',
#   'помощница',
#   'швейный',
#   'машинка',
#   'даже',
#   'подшить',
#   'подол',
#   'платье',
#   'укоротить',
#   'ребёнок',
#   'штаны',
#   'быстрый',
#   'аккуратный',
#   'получиться',
#   'машинка',
#   'разновидность',
#   'великое',
#   'множество',
#   'это',
#   'отечественный',
#   'импортный',
#   'модель',
#   'существовать',
#   '270',
#   'различный',
#   'модель',
#   'jaguar',
#   'статья',
#   'поговорить',
#   'самый',
#   'популярный',
#   'функциональный',
#   'компания',
#   'jaguar',
#   'основать',
#   'япония',
#   '1949',
#   'год',
#   'называться',
#   'изначально',
#   'maruzen',
#   'mischin',
#   'company',
#   'начинать',
#   'работать',
#   'продавать',
#   'швейный',
#   'машина',
#   'запасный',
#   'деталь',
#   'оптом',
#   'спустя',
#   '3',
#   'год',
#   'поток',
#   'поставить',
#   'выпуск',
#   'один',
#   'японский',
#   'машинка',
#   'шитьё',
#   'который',
#   'уметь',
#   'шить',
#   'прямая',
#   'строчка',
#   'зигзаг',
#   'высокий',
#   'качество',
#   'товар',
#   'привлечь',
#   'внимание',
#   'зарубежный',
#   'партнёр',
#   'в',
#   'тандем',
#   'американский',
#   'торговый',
#   'компания',
#   'sears',
#   'roebuck',
#   'maruzen',
#   'выходить',
#   'мировой',
#   'рынок',
#   'продажа',
#   'в',
#   '1968',
#   'год',
#   'компания',
#   'sears',
#   'roebuck',
#   'отмечать',
#   'деятельность',
#   'maruzen',
#   'награда',
#   'качество',
#   'продукция',
#   'производство',
#   'расширяться',
#   'год',
#   'год',
#   'спрос',
#   'продукция',
#   'расти',
#   'фирма',
#   'открывать',
#   'свой',
#   'представительство',
#   'брюссель',
#   'дюссельдорф',
#   'также',
#   'новое',
#   'производство',
#   'появляться',
#   'тайвань',
#   'в',
#   '1973',
#   'год',
#   'выпуск',
#   'машина',
#   'вырастать',
#   '5',
#   '000',
#   '000',
#   'экземпляр',
#   '5',
#   'год',
#   '7',
#   '000',
#   '000',
#   'компания',
#   'стать',
#   'называться',
#   'jaguar',
#   'sewing',
#   'machines',
#   'company',
#   'в',
#   '1995',
#   'год',
#   'запускаться',
#   'крупный',
#   'завод',
#   'в',
#   'разный',
#   'год',
#   'конец',
#   'прошлое',
#   'век',
#   'продукция',
#   'концерн',
#   'множество',
#   'отмечаться',
#   'престижный',
#   'награда',
#   'высокий',
#   'качество',
#   'вид',
#   'машинка',
#   'jaguar',
#   'на',
#   'сегодняшний',
#   'день',
#   'машинка',
#   'оверлока',
#   'японский',
#   'фирма',
#   'ягуар',
#   'один',
#   'хороший',
#   'мир',
#   'они',
#   'делиться',
#   '3',
#   'класс',
#   'бюджетный',
#   'высокий',
#   'портативный',
#   'агрегат',
#   'бюджетный',
#   'класс',
#   'выполнять',
#   'простейшее',
#   'задача',
#   'иметь',
#   'минимальный',
#   'набор',
#   'операция',
#   'это',
#   'строчка',
#   'прямая',
#   'зигзаг',
#   'штопка',
#   'потайной',
#   'строчка',
#   'пришивание',
#   'пуговица',
#   'они',
#   'простой',
#   'использование',
#   'работать',
#   'надёжно',
#   'если',
#   'заниматься',
#   'шитьё',
#   'использовать',
#   'материал',
#   'разный',
#   'качество',
#   'толщина',
#   'осуществление',
#   'свой',
#   'намерение',
#   'нужный',
#   'машинка',
#   'больший',
#   'набор',
#   'операция',
#   'она',
#   'должный',
#   'иметь',
#   'функция',
#   'обработка',
#   'край',
#   'люба',
#   'ткань',
#   'трикотажный',
#   'шов',
#   'полуавтоматический',
#   'отделка',
#   'петлить',
#   'у',
#   'модель',
#   'бюджетный',
#   'класс',
#   'количество',
#   'поддерживать',
#   'функция',
#   'около',
#   '20',
#   'хватить',
#   'люба',
#   'хозяйка',
#   'который',
#   'зарабатывать',
#   'шитьё',
#   'периодически',
#   'пользоваться',
#   'машинка',
#   'бытовой',
#   'дело',
#   'самый',
#   'известный',
#   'бюджетный',
#   'модель',
#   'управление',
#   'электромеханик',
#   'качаться',
#   'челнок',
#   'скорость',
#   'шитьё',
#   'плавно',
#   'регулироваться',
#   'присутствовать',
#   'реверсный',
#   'кнопка',
#   'аппарат',
#   'автоматически',
#   'измерять',
#   'размер',
#   'пуговица',
#   'ширина',
#   'длина',
#   'стежок',
#   '5',
#   '45',
#   'миллиметр',
#   'соответственно',
#   'строка',
#   'который',
#   'делать',
#   'машинка',
#   'эластичный',
#   'обметочный',
#   'оверлочный',
#   'потаённый',
#   'конструкция',
#   'предусматривать',
#   'спец',
#   'отдел',
#   'различный',
#   'аксессуар',
#   'автовдеватель',
#   'нить',
#   'мягкий',
#   'чехол',
#   'иметься',
#   'лапка',
#   'выполнять',
#   'следующий',
#   'функция',
#   'вшивка',
#   'молния',
#   'подрубка',
#   'квилтинг',
#   'обмётка',
#   'оверлок',
#   'габарит',
#   '35х26х16',
#   'сантиметр',
#   'вес',
#   'семь',
#   'килограмм',
#   'полный',
#   'комплект',
#   'jaguar',
#   '316',
#   'электромеханический',
#   'управление',
#   'возможность',
#   'регулировать',
#   'степень',
#   'давление',
#   'лапка',
#   'реверсионный',
#   'кнопка',
#   'светодиодный',
#   'освещение',
#   'процесс',
#   'шитьё',
#   'измерение',
#   'размер',
#   'пуговица',
#   'автоматический',
#   'петлить',
#   'выполняться',
#   'полуавтоматический',
#   'режим',
#   'длина',
#   'ширина',
#   'стежок',
#   '45',
#   '5',
#   'мм',
#   'соответственно',
#   '5',
#   'стандартный',
#   'вид',
#   'строчка',
#   'смвыше',
#   'чехол',
#   'нитевдеватель',
#   'отсечь',
#   'деталь',
#   'функция',
#   'лапка',
#   'вшивка',
#   'молния',
#   'оверлок',
#   'обмётка',
#   'габарит',
#   '35х26х16',
#   'сантиметр',
#   'вес',
#   'семь',
#   'килограмм',
#   'полный',
#   'комплект',
#   'jaguar',
#   '745',
#   'тип',
#   'управление',
#   'электромеханик',
#   'реверсионный',
#   'кнопка',
#   'управление',
#   'подъём',
#   'лапка',
#   'высота',
#   '10',
#   'миллиметр',
#   'освещение',
#   'светодиодный',
#   'система',
#   'определение',
#   'размер',
#   'пуговица',
#   '5',
#   'стандартный',
#   'вид',
#   'строчка',
#   'лапка',
#   'вшивание',
#   'молния',
#   'квилтинговый',
#   'в',
#   'конструкция',
#   'предусмотреть',
#   'стол',
#   'расширять',
#   'рабочий',
#   'поверхность',
#   'в',
#   'комплект',
#   'чехол',
#   'мягкий',
#   'материал',
#   'jaguar',
#   '777',
#   'более',
#   'эргономичный',
#   'расположение',
#   'элемент',
#   'управление',
#   'коллега',
#   'цех',
#   'горизонтальный',
#   'челнок',
#   'автовыметка',
#   'петля',
#   'возможность',
#   'шить',
#   'двойной',
#   'игла',
#   'нижний',
#   'рейка',
#   'иметь',
#   'опция',
#   'отключение',
#   'в',
#   'наличие',
#   'электронный',
#   'педаль',
#   'ширина',
#   'зигзаг',
#   'доходить',
#   '65',
#   'миллиметр',
#   'стандартный',
#   'комплект',
#   'отсечь',
#   'аксессуар',
#   'чехол',
#   'пр',
#   'jaguar',
#   '551',
#   'главный',
#   'отличительный',
#   'черта',
#   'дать',
#   'ценовый',
#   'сегмент',
#   'компактность',
#   'вместе',
#   'это',
#   'больший',
#   'вес',
#   'количество',
#   'швейный',
#   'операция',
#   '14',
#   'рукав',
#   'свободный',
#   'встроить',
#   'светодиодный',
#   'освещение',
#   'расположение',
#   'челнок',
#   'вертикально',
#   'габарит',
#   'стандартный',
#   'набор',
#   'деталь',
#   'стандартный',
#   'вес',
#   '78',
#   'килограмм',
#   'наиболее',
#   'функциональный',
#   'аппарат',
#   'серия',
#   'бюджетный',
#   'появление',
#   'новый',
#   'строчка',
#   'подшивочный',
#   'декоративный',
#   'трикотажный',
#   'расположение',
#   'челнок',
#   'позволять',
#   'комфортно',
#   'работать',
#   'трудный',
#   'материал',
#   'трикотаж',
#   'шёлк',
#   'кожа',
#   'отсутствовать',
#   'необходимость',
#   'смазка',
#   'наличие',
#   'рычаг',
#   'электронный',
#   'заклёпка',
#   'количество',
#   'рабочий',
#   'операция',
#   '40',
#   'реверс',
#   'электронный',
#   'позиционер',
#   'игла',
#   'электронный',
#   'встроить',
#   'система',
#   'безопасность',
#   'чехол',
#   'жёсткий',
#   'наличие',
#   'вспарыватель',
#   'щётка',
#   'отвётка',
#   'пр',
#   'габарит',
#   '41х17х30',
#   'сантиметр',
#   'вес',
#   '112',
#   'килограмм',
#   'для',
#   'профессиональный',
#   'работа',
#   'использовать',
#   'высокий',
#   'класс',
#   'швейный',
#   'машина',
#   'они',
#   'иметь',
#   'обширный',
#   'возможность',
#   'автоматический',
#   'обметывание',
#   'петля',
#   'нитевдеватель',
#   'разный',
#   'вид',
#   'декоративный',
#   'стачной',
#   'шов',
#   'горизонтальный',
#   'челнок',
#   'упрощать',
#   'заправка',
#   'нить',
#   'повышать',
#   'качество',
#   'строчка',
#   'машинка',
#   'высокий',
#   'класс',
#   'работать',
#   'бесшумно',
#   'простой',
#   'обращение',
#   'иметь',
#   'практически',
#   'неограниченный',
#   'возможность',
#   'электронный',
#   'машинка',
#   'автоматически',
#   'настраиваться',
#   'регулироваться',
#   'операция',
#   'помощь',
#   'компьютер',
#   'большой',
#   '300',
#   'разновидность',
#   'стачной',
#   'декоративный',
#   'шов',
#   'вышивание',
#   'различный',
#   'техник',
#   'невозможный',
#   'этот',
#   'совершенный',
#   'модель',
#   'причём',
#   'выполнить',
#   'самый',
#   'сложный',
#   'задача',
#   'умный',
#   'машинка',
#   'смочь',
#   'начинающий',
#   'швея',
#   'самый',
#   'известный',
#   'модель',
#   'высокий',
#   'класс',
#   'количество',
#   'швейный',
#   'операция',
#   '28',
#   'челнок',
#   'ротационный',
#   'горизонтальный',
#   '13',
#   'тип',
#   'поддерживать',
#   'строчка',
#   'независимый',
#   'регулировка',
#   'длина',
#   'стежок',
#   'скорость',
#   'шитьё',
#   '600',
#   'стежок',
#   'минута',
#   'подъём',
#   'лапка',
#   '9',
#   'миллиметр',
#   'семисегментный',
#   'нижний',
#   'транспортёр',
#   'в',
#   'комплект',
#   'присутствовать',
#   'лапка',
#   'алтасный',
#   'декоративный',
#   'строчка',
#   'монограмма',
#   'энергопотребление',
#   '75',
#   'ватт',
#   'стандартный',
#   'комплект',
#   'вес',
#   '8',
#   'килограмм',
#   'инструкция',
#   'швейный',
#   'машина',
#   'jaguar',
#   '977',
#   'pdf',
#   '744',
#   'мб',
#   'jaguar',
#   '979',
#   'электромеханический',
#   'управление',
#   'плавный',
#   'регулировка',
#   'скорость',
#   'шитьё',
#   'освещение',
#   'светодиод',
#   '5',
#   'вид',
#   'исполняемый',
#   'строчка',
#   '3',
#   'вид',
#   'лапка',
#   'страна',
#   'производитель',
#   'тайланд',
#   'количество',
#   'швейный',
#   'операция',
#   '40',
#   'плавно',
#   'регулировать',
#   'давление',
#   'лапка',
#   'ткань',
#   'объёмный',
#   'отсечь',
#   'аксессуар',
#   'габарит',
#   '41х17х30',
#   'сантиметр',
#   'вес',
#   '73',
#   'килограмм',
#   'инструкция',
#   'швейный',
#   'машина',
#   'jaguar',
#   '979',
#   'pdf',
#   '744',
#   'мб',
#   'jaguar',
#   '6434',
#   'управление',
#   'электронный',
#   '5',
#   'стандартный',
#   'тип',
#   'лапка',
#   'пространство',
#   'свободный',
#   'рукав',
#   'длина',
#   'ширина',
#   'стежок',
#   '4',
#   '5',
#   'сантиметр',
#   'соответственно',
#   'челнок',
#   'вертикальный',
#   'комплектация',
#   'стандартный',
#   'габарит',
#   '28х17х38',
#   'сантиметр',
#   'вес',
#   '57',
#   'килограмм',
#   '3',
#   'для',
#   'транспортировка',
#   'работа',
#   'условие',
#   'постоянный',
#   'перемещение',
#   'концерн',
#   'разработать',
#   'портативный',
#   'аппарат',
#   'jaguar',
#   '271',
#   'mini',
#   'он',
#   'иметь',
#   'скоростной',
#   'режим',
#   'обычный',
#   'строчка',
#   'делать',
#   'большой',
#   'скорость',
#   'сложный',
#   'работа',
#   'медленный',
#   'потеря',
#   'качество',
#   'строчить',
#   'машинка',
#   'прямая',
#   'строчка',
#   'зигзаг',
#   'потайной',
#   'запошивочный',
#   'шов',
#   'уметь',
#   'делать',
#   'рельефный',
#   'рубчик',
#   'атласный',
#   'строчка',
#   'можно',
#   'пришивать',
#   'пуговица',
#   'вышивать',
#   'гладь',
#   'выполнять',
#   'накладный',
#   'аппликация',
#   'jaguar',
#   '271',
#   'управление',
#   'электромеханик',
#   'реверсионный',
#   'кнопка',
#   'автоподъём',
#   'лапка',
#   'количество',
#   'выполнять',
#   'операция',
#   '8',
#   'полуавтоматический',
#   'выполнение',
#   'петлить',
#   'возможность',
#   'сделать',
#   'обметочный',
#   'строчка',
#   'дисплей',
#   'отсутствовать',
#   'комплектация',
#   'стандартный',
#   'вес',
#   '42',
#   'килограмм',
#   'инструкция',
#   'швейный',
#   'машинка',
#   'ягуар',
#   'минь',
#   '271',
#   'pdf',
#   '243',
#   'мб',
#   'комплектовать',
#   'подавлять',
#   'большинство',
#   'модель',
#   'машинка',
#   'упаковать',
#   'мягкий',
#   'чехол',
#   'аппарат',
#   'электромеханический',
#   'привод',
#   'работать',
#   'люба',
#   'нить',
#   'игла',
#   'они',
#   'производить',
#   'таиланд',
#   'дочерний',
#   'предприятие',
#   'с',
#   'помощь',
#   'стачивать',
#   'обрабатывать',
#   'самый',
#   'разный',
#   'ткань',
#   'следовать',
#   'правильно',
#   'подобрать',
#   'поменять',
#   'иглу',
#   'нитка',
#   'тип',
#   'челнок',
#   'постоянный',
#   'режим',
#   'он',
#   'делать',
#   '16',
#   'различный',
#   'вид',
#   'работа',
#   'для',
#   'удобство',
#   'машинка',
#   'оснастить',
#   'электронный',
#   'педальюширин',
#   'строчка',
#   'зигзаг',
#   '5',
#   'мм',
#   'регулироваться',
#   'длина',
#   'стежок',
#   'тип',
#   'челнок',
#   'преимущественно',
#   'качаться',
#   'универсальный',
#   'инструкция',
#   'машинка',
#   'ягуар',
#   '312',
#   '316',
#   '745',
#   '777',
#   '551',
#   '791',
#   '6434',
#   'устройство',
#   'швейный',
#   'машинка',
#   'устройство',
#   'швейный',
#   'машинка',
#   'устройство',
#   'швейный',
#   'машинка',
#   'инструкция',
#   'заправка',
#   'верхний',
#   'нитка',
#   'инструкция',
#   'заправка',
#   'верхний',
#   'нитка',
#   'инструкция',
#   'установка',
#   'иголка',
#   'швейный',
#   'машина',
#   'инструкция',
#   'установка',
#   'иголка',
#   'швейный',
#   'машина',
#   'инструкция',
#   'намотка',
#   'нитка',
#   'шпулька',
#   'инструкция',
#   'намотка',
#   'нитка',
#   'шпулька',
#   'заправка',
#   'нижний',
#   'нитка',
#   'шпульный',
#   'колпачок',
#   'заправка',
#   'нижний',
#   'нитка',
#   'шпульный',
#   'колпачок',
#   '2',
#   'замена',
#   'лапка',
#   'швейный',
#   'машиныобратный',
#   'ход',
#   'швейный',
#   'машина',
#   'принадлежность',
#   'аксессуар',
#   'швейный',
#   'машина'],
#  ['компактный',
#   'электромеханический',
#   'швейный',
#   'машина',
#   'jaguar',
#   'vx7',
#   'выполнять',
#   '9',
#   'вид',
#   'строчка',
#   'петлить',
#   'пол',
#   'автоматический',
#   'режим',
#   'машина',
#   'справляться',
#   'различный',
#   'тип',
#   'ткань',
#   'функциональность',
#   'швейный',
#   'машина',
#   'jaguar',
#   'vx7',
#   'достаточный',
#   'использование',
#   'ремонт',
#   'одежда',
#   'пошив',
#   'изделие',
#   'различный',
#   'ткань',
#   'материал'],
#  ['jaguar',
#   '333',
#   'это',
#   'один',
#   'современный',
#   'домашний',
#   'швейный',
#   'машинка',
#   'до',
#   'шить',
#   'старый',
#   'бабушкин',
#   'зингер',
#   'ножной',
#   'привод',
#   'и',
#   'принцип',
#   'весь',
#   'устраивать',
#   'бабушкин',
#   'древность',
#   'сто',
#   'год',
#   'обед',
#   'но',
#   '4',
#   'год',
#   'назад',
#   'папа',
#   'всётаки',
#   'решить',
#   'подарить',
#   'день',
#   'рождение',
#   'новый',
#   'электрический',
#   'швейный',
#   'машина'],
#  ['компания',
#   'jaguar',
#   'основать',
#   'япония',
#   '1949',
#   'год',
#   'называться',
#   'изначально',
#   'maruzen',
#   'mischin',
#   'company',
#   'начинать',
#   'работать',
#   'продавать',
#   'швейный',
#   'машина',
#   'запасный',
#   'деталь',
#   'оптом',
#   'спустя',
#   '3',
#   'год',
#   'поток',
#   'поставить',
#   'выпуск',
#   'один',
#   'японский',
#   'машинка',
#   'шитьё',
#   'который',
#   'уметь',
#   'шить',
#   'прямая',
#   'строчка',
#   'зигзаг',
#   'высокий',
#   'качество',
#   'товар',
#   'привлечь',
#   'внимание',
#   'зарубежный',
#   'партнёр',
#   'в',
#   'тандем',
#   'американский',
#   'торговый',
#   'компания',
#   'sears',
#   'roebuck',
#   'maruzen',
#   'выходить',
#   'мировой',
#   'рынок',
#   'продажа'],
#  ['неожиданно',
#   'наличие',
#   'светодиодный',
#   'освещение',
#   'нитевдеватель',
#   'поскольку',
#   'дать',
#   'модель',
#   'нож',
#   'обрезка',
#   'нить',
#   'корпус',
#   'для',
#   'обрезка',
#   'нить',
#   'предусмотреть',
#   'специальный',
#   'приспособление',
#   'стержень',
#   'лапкодержатель',
#   'весьма',
#   'удобно'],
#  ['компактный',
#   'электромеханический',
#   'швейный',
#   'машина',
#   'jaguar',
#   'vx7',
#   'выполнять',
#   '9',
#   'вид',
#   'строчка',
#   'петлить',
#   'пол',
#   'автоматический',
#   'режим',
#   'машина',
#   'справляться',
#   'различный',
#   'тип',
#   'ткань',
#   'функциональность',
#   'швейный',
#   'машина',
#   'jaguar',
#   'vx7',
#   'достаточный',
#   'использование',
#   'ремонт',
#   'одежда',
#   'пошив',
#   'изделие',
#   'различный',
#   'ткань',
#   'материал']]

# %%
model = Word2Vec(abstracts[0], size=300, window=5, min_count=5, iter=10)
model.init_sims(replace = True)
model.save("word2vec.model")
# Out:
# c:\users\qwe\appdata\local\programs\python\python36\lib\site-packages\gensim\models\base_any2vec.py:743: UserWarning: C extension not loaded, training will be slow. Install a C compiler and reinstall gensim for fast training.
#   "C extension not loaded, training will be slow. "

# %%
from collections import Counter

cnt = Counter()
for abstract in abstracts[0]:
    cnt.update(abstract)

# %%
#terms = [i[0] for i in cnt.most_common(5000)]
terms = [i[0] for i in cnt.most_common(5000) ]

# %%
terms_vec = model[terms]
# Out:
# c:\users\qwe\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-9d61e0bac454> in <module>
# ----> 1 terms_vec = model[terms]
#
# c:\users\qwe\appdata\local\programs\python\python36\lib\site-packages\gensim\utils.py in new_func1(*args, **kwargs)
#    1445                     stacklevel=2
#    1446                 )
# -> 1447                 return func(*args, **kwargs)
#    1448
#    1449             return new_func1
#
# c:\users\qwe\appdata\local\programs\python\python36\lib\site-packages\gensim\models\word2vec.py in __getitem__(self, words)
#    1119
#    1120         """
# -> 1121         return self.wv.__getitem__(words)
#    1122
#    1123     @deprecated("Method will be removed in 4.0.0, use self.wv.__contains__() instead")
#
# c:\users\qwe\appdata\local\programs\python\python36\lib\site-packages\gensim\models\keyedvectors.py in __getitem__(self, entities)
#     352             return self.get_vector(entities)
#     353
# --> 354         return vstack([self.get_vector(entity) for entity in entities])
#     355
#     356     def __contains__(self, entity):
#
# c:\users\qwe\appdata\local\programs\python\python36\lib\site-packages\gensim\models\keyedvectors.py in <listcomp>(.0)
#     352             return self.get_vector(entities)
#     353
# --> 354         return vstack([self.get_vector(entity) for entity in entities])
#     355
#     356     def __contains__(self, entity):
#
# c:\users\qwe\appdata\local\programs\python\python36\lib\site-packages\gensim\models\keyedvectors.py in get_vector(self, word)
#     468
#     469     def get_vector(self, word):
# --> 470         return self.word_vec(word)
#     471
#     472     def words_closer_than(self, w1, w2):
#
# c:\users\qwe\appdata\local\programs\python\python36\lib\site-packages\gensim\models\keyedvectors.py in word_vec(self, word, use_norm)
#     465             return result
#     466         else:
# --> 467             raise KeyError("word '%s' not in vocabulary" % word)
#     468
#     469     def get_vector(self, word):
#
# KeyError: "word 'хищный' not in vocabulary"

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0)
terms_tsne = tsne.fit_transform(terms_vec)
#plot TSNE
from bokeh.models import ColumnDataSource, HoverTool
from bokeh.plotting import figure, show, output_file
from bokeh.io import output_notebook
output_notebook()

source = ColumnDataSource(data=dict(x1=terms_tsne[:,0],
                                    x2=terms_tsne[:,1],
                                    labels = terms))

hover = HoverTool(tooltips = [("label","@labels")])

p = figure(title="TSNE for terms", tools = [hover])



p.scatter(x="x1", y="x2", size=3, source=source)

from scipy.cluster.hierarchy import  ward, dendrogram

linkage_matrix = ward(dist) 
fig, ax = pyplot.subplots(figsize=(10, 250)) 
ax = dendrogram(linkage_matrix, orientation="right", labels=terms);

pyplot.tick_params(\
    axis= 'x',          
    which='both',      
    bottom='off',   
    top='off',      
    labelbottom='off')

pyplot.tight_layout() 

pyplot.savefig('w2v_clusters.png', dpi=200)

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0)
terms_tsne = tsne.fit_transform(terms_vec)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()

# %%
corpus = [' '.join(a) for a in abstracts[0]]

# %%
X = vectorizer.fit_transform(corpus)
print(vectorizer.get_feature_names())

# %%
# %matplotlib inline
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import numpy as np

# %%
data = []
data.append(np.array(X))

# %%
data.append(np.array(model))

# %%
cl = KMeans(n_clusters=2, random_state=1234)

# %%
kk = np.array(cl.fit(X))

# %%
from scipy.cluster.hierarchy import  ward, dendrogram

linkage_matrix = ward(kk) 
fig, ax = pyplot.subplots(figsize=(10, 250)) 
ax = dendrogram(linkage_matrix, orientation="right", labels=terms);

pyplot.tick_params(\
    axis= 'x',          
    which='both',      
    bottom='off',   
    top='off',      
    labelbottom='off')

pyplot.tight_layout() 

pyplot.savefig('w2v_clusters.png', dpi=200)
